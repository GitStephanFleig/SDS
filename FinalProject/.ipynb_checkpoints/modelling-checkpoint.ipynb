# %% [markdown]
# # Data structuring

# %%
# Loading packages

import requests
from bs4 import BeautifulSoup
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load df from disk

df = pd.read_csv("speeches/data.csv")

# %%
df.head()

# %%
len(df)

# %%
df["Speech"] = df["Speech"].str.replace("transcript-inner", "").str.replace(u'\xa0', u' ')

# %%
print(df['Speech'].loc[9])

# %%
# drops party orientation that isn't Rep or Dem
df2 = df.drop(df.index[92:108])

# %%
df2.head()

# %%
# creates party dummy
Party_dummy = pd.get_dummies(df2['Party'], drop_first=True)
# Party_dummy
# Out:
#     Republican
# 0            1
# 1            1
# 2            1
# 3            0
# 4            0
# 5            0
# 6            0
# 7            0
# 8            0
# 9            0
# 10           0
# 11           0
# 12           1
# 13           1
# 14           1
# 15           1
# 16           1
# 17           1
# 18           1
# 19           1
# 20           1
# 21           0
# 22           0
# 23           0
# 24           0
# 25           0
# 26           0
# 27           0
# 28           1
# 29           1
# ..         ...
# 62           0
# 63           0
# 64           0
# 65           0
# 66           0
# 67           0
# 68           1
# 69           1
# 70           1
# 71           1
# 72           1
# 73           1
# 74           1
# 75           0
# 76           0
# 77           0
# 78           1
# 79           1
# 80           1
# 81           0
# 82           1
# 83           0
# 84           1
# 85           1
# 86           1
# 87           1
# 88           1
# 89           1
# 90           0
# 91           0
#
# [92 rows x 1 columns]

# %%
df2['Republican'] = Party_dummy

# %%
df2.head()
print(len(df2))

# %%
#Number of words in each speech
df2["word_count"] = df2["Speech"].apply(lambda x : len(x))
#Number of unique words in each speech
df2["unique_word"] = df2["Speech"].apply(lambda x : len(set(x.lower().split()) ) )
#Number of unique words ratio in each speech
df2["unique_word_ratio"] = df2.apply(lambda x : x["unique_word"]/x["word_count"] ,axis=1)
#Extracting year alone from the Date column
df2["year"] = df2["Date"].apply(lambda x : int(x.split(",")[2])  if len(x.split(","))==3 else int(x.split(",")[1]) )
df2.head()
# Out:
#    Unnamed: 0          Name               Date  \
# 0           0  Donald Trump  February 05, 2019
# 1           1  Donald Trump   January 30, 2018
# 2           2  Donald Trump   January 20, 2017
# 3           3  Barack Obama   January 12, 2016
# 4           4  Barack Obama   January 20, 2015
#
#                                               Speech                Type  \
# 0  \r\n      Transcript\r\n      \r\nMadam Speake...  State of the Union
# 1  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 2  \r\n      Transcript\r\n      Chief Justice Ro...   Inaugural Address
# 3  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 4  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
#
#         Party  Republican  word_count  unique_word  unique_word_ratio  year
# 0  Republican           1       30958         1910           0.061696  2019
# 1  Republican           1       30550         1906           0.062390  2018
# 2  Republican           1        8561          622           0.072655  2017
# 3    Democrat           0       35420         1931           0.054517  2016
# 4    Democrat           0       40487         2068           0.051078  2015

# %%
print(df2['Party'])

# %%
sns.set_style("darkgrid")
ax = sns.boxplot(x='Type', y="word_count", orient='v', hue='Republican', data=df2)
plt.title("Box plot of Word Count")
plt.xlabel("")
plt.ylabel("Word count")

# %%
max(df2['word_count'])
min(df2['word_count'])

# %%
# Trying to make to new dataframes; one with InAug speeches and one 
# with State.

df_inaug = []
df_state = []

for speech in df2['Type']:
    if 'Type'=='Inaugural Address':
        df_inaug.append
    else:
        df_state.append


#df_by_speech = df2.groupby('Type').head()

df_inaug = [g for _, g in df2.groupby('Type'=='Inaugural Address')]
df_state = [g for _, g in df2.groupby('Type'=='State of the Union')]

# %%
df_inaug = df_by_speech['Type'=='Inaugural Adress']
df_inaug
print(len(df_inaug))
df_state = df_by_speech['Type'=='State of the Union']
print(len(df_state))

# %%
# state of the union dataset
df_speech_des = df2.groupby('Type').describe().head()

# %%
df_speech_des.head()

# %%
df_speech_des['word_count']
with open('mytable.tex','w') as tf:
    tf.write(df_by_speech.to_latex())

# %%
timeline = sns.catplot(x="year",y="word_count",hue="Party",data=df2,kind="bar",height=5,aspect=2,legend_out=False)
timeline.set_xticklabels(rotation=90)
plt.title("Year wise Speech Length")
plt.ylabel("")
# Out:
# Text(-8.700000000000003, 0.5, '')

# %% [markdown]
# # Text analysis

# %%
# Download positive and negative sentiment lexicons, split into words and convert to set representation. 
negative = set(requests.get('http://ptrckprry.com/course/ssd/data/negative-words.txt').text.split(';\n')[-1].split('\n'))
positive = set(requests.get('http://ptrckprry.com/course/ssd/data/positive-words.txt').text.split(';\n')[-1].split('\n'))
print(len(negative),len(positive))
# Out:
# 4784 2007

# %%
# initialize tokenizer
#import nltk
#nltk.download('punkt')

from nltk import sent_tokenize, word_tokenize
#tokenizer = sent_tokenize

# %%
# define function
def sent_preproc(string):
    return sent_tokenize(string.lower())

# %%
def word_preproc(string):
    return word_tokenize(string.lower())

# %%
# apply function
sentences = df2.Speech.apply(sent_preproc)

# %%
words = df2.Speech.apply(word_preproc)

# %%
sentences.head()
# Out:
# 0    [\r\n      transcript\r\n      \r\nmadam speak...
# 1    [\r\n      transcript\r\n      mr. speaker, mr...
# 2    [\r\n      transcript\r\n      chief justice r...
# 3    [\r\n      transcript\r\n      mr. speaker, mr...
# 4    [\r\n      transcript\r\n      mr. speaker, mr...
# Name: Speech, dtype: object

# %%
words.head()
# Out:
# 0    [transcript, madam, speaker, ,, mr., vice, pre...
# 1    [transcript, mr., speaker, ,, mr., vice, presi...
# 2    [transcript, chief, justice, roberts, ,, presi...
# 3    [transcript, mr., speaker, ,, mr., vice, presi...
# 4    [transcript, mr., speaker, ,, mr., vice, presi...
# Name: Speech, dtype: object

# %%
# Defines function for counting number of matches with pos/neg words
def count_dictionary(tokenized_doc,dictionary):
    return len([word for word in tokenized_doc if word in dictionary])

# %%
df2['positive_words'] = words.apply(count_dictionary,dictionary=positive)
df2['negative_words'] = words.apply(count_dictionary,dictionary=negative)

# %%
# positive and negative words to total words ration
df2["positive_words_ratio"] = df2['positive_words']/df2['word_count']
df2["negative_words_ratio"] = df2['negative_words']/df2['word_count']

# %%
df2
# Out:
#     Unnamed: 0                   Name               Date  \
# 0            0           Donald Trump  February 05, 2019
# 1            1           Donald Trump   January 30, 2018
# 2            2           Donald Trump   January 20, 2017
# 3            3           Barack Obama   January 12, 2016
# 4            4           Barack Obama   January 20, 2015
# 5            5           Barack Obama   January 28, 2014
# 6            6           Barack Obama  February 13, 2013
# 7            7           Barack Obama   January 21, 2013
# 8            8           Barack Obama   January 24, 2012
# 9            9           Barack Obama   January 25, 2011
r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 10  \r\n      Transcript\r\n      Madam Speaker, V...  State of the Union
# 11  \r\n      Transcript\r\n      I stand here tod...   Inaugural Address
# 12  \r\n      Transcript\r\n      Madam Speaker, V...  State of the Union
# 13  \r\n      Transcript\r\n      Thank you very m...  State of the Union
# 14  \r\n      Transcript\r\n      Thank you all. M...  State of the Union
# 15  \r\n      Transcript\r\n      Mr. Speaker, Vic...  State of the Union
# 16  \r\n      Transcript\r\n      Vice President C...   Inaugural Address
# 17  \r\n      Transcript\r\n      Mr. Speaker, Vic...  State of the Union
# 18  \r\n      Transcript\r\n      Mr. Speaker, Vic...  State of the Union
# 19  \r\n      Transcript\r\n      Thank you very m...  State of the Union
# 20  \r\n      Transcript\r\n      President Clinto...   Inaugural Address
# 21  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 22  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 23  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 24  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 25  \r\n      Transcript\r\n      Mr. Speaker, Mr....  State of the Union
# 26  \r\n      Transcript\r\n      Mr. President, M...  State of the Union
# 27  \r\n      Transcript\r\n      Thank you very m...  State of the Union
# 28  \r\n      Transcript\r\n      Mr. Speaker and ...  State of the Union
# 29  \r\n      Transcript\r\n      Mr. President an...  State of the Union
# ..                                                ...                 ...
# 62  \r\n      Transcript\r\n      Mr. Vice Preside...   Inaugural Address
# 63  \r\n      Transcript\r\n      Mr. Chief Justic...   Inaugural Address
# 64  \r\n      Transcript\r\n      Mr. Vice Preside...  State of the Union
# 65  \r\n      Transcript\r\n      On each national...   Inaugural Address
# 66  \r\n      Transcript\r\n      When four years ...   Inaugural Address
# 67  \r\n      Transcript\r\n      President Hoover...   Inaugural Address
# 68  Transcriptview-transcriptTo the Senate and Hou...  State of the Union
# 69  Transcriptview-transcriptTo the Senate and Hou...  State of the Union
# 70  Transcriptview-transcriptTo the Senate and Hou...  State of the Union
# 71  Transcriptview-transcriptTo the Senate and Hou...  State of the Union
# 72  Transcriptview-transcriptMy Countrymen: view-t...   Inaugural Address
# 73  Transcriptview-transcriptMy Countrymen: view-t...   Inaugural Address
# 74  Transcriptview-transcriptMy Countrymen: view-t...   Inaugural Address
# 75  Transcriptview-transcriptMy Fellow Citizens: v...   Inaugural Address
# 76  Transcriptview-transcriptThere has been a chan...   Inaugural Address
# 77  Transcriptview-transcriptMy Fellow-Citizens: v...   Inaugural Address
# 78  Transcriptview-transcriptMy fellow-citizens, n...   Inaugural Address
# 79  Transcriptview-transcriptMy Fellow-Citizens: v...   Inaugural Address
# 80  Transcriptview-transcriptFellow-Citizens: view...   Inaugural Address
# 81  Transcriptview-transcriptMy Fellow-Citizens: v...   Inaugural Address
# 82  Transcriptview-transcriptFellow-Citizens: view...   Inaugural Address
# 83  Transcriptview-transcriptFellow-Citizens: view...   Inaugural Address
# 84  Transcriptview-transcriptFellow-Citizens: view...   Inaugural Address
# 85  Transcriptview-transcriptFellow-Citizens: view...   Inaugural Address
# 86  Transcriptview-transcriptFellow-Citizens: view...   Inaugural Address
# 87  Transcriptview-transcriptCitizens of the Unite...   Inaugural Address
# 88  Transcriptview-transcriptFellow-Countrymen:vie...   Inaugural Address
# 89  Transcriptview-transcript view-transcriptFello...   Inaugural Address
# 90  Transcriptview-transcriptFellow-Citizens:view-...   Inaugural Address
# 91  Transcriptview-transcriptMy Countrymen: view-t...   Inaugural Address
#
#          Party  Republican  word_count  unique_word  unique_word_ratio  year  \
# 0   Republican           1       30958         1910           0.061696  2019
# 1   Republican           1       30550         1906           0.062390  2018
# 2   Republican           1        8561          622           0.072655  2017
# 3     Democrat           0       35420         1931           0.054517  2016
# 64              0.007088              0.005306
# 65              0.006246              0.003774
# 66              0.008478              0.006688
# 67              0.009026              0.006860
# 68              0.006125              0.003855
# 69              0.005601              0.003418
# 70              0.004400              0.003540
# 71              0.005092              0.002876
# 72              0.007870              0.004118
# 73              0.008589              0.003419
# 74              0.008998              0.005108
# 75              0.006089              0.002819
# 76              0.007860              0.005921
# 77              0.007566              0.003212
# 78              0.008808              0.003955
# 79              0.007733              0.003420
# 80              0.008976              0.002879
# 81              0.009611              0.006354
# 82              0.008329              0.003672
# 83              0.009617              0.004371
# 84              0.008046              0.004470
# 85              0.008641              0.002704
# 86              0.006343              0.003298
# 87              0.007984              0.002260
# 88              0.006216              0.006216
# 89              0.006012              0.005318
# 90              0.008640              0.003787
# 91              0.009187              0.004244
#
# [92 rows x 17 columns]

# %% [markdown]
# ## Positive and negative words

# %%
# plotting positive and negative words against each other 
sentiment = sns.lineplot(x="year",y="positive_words", hue='Republican', data=df2)
sentiment = sns.lineplot(x="year",y="negative_words", hue='Republican', data=df2)
plt.show()

#timeline.set_xticklabels(rotation=90)
#plt.title("Year wise Speech Length")
#plt.ylabel("")

# %% [markdown]
# ## Positive and negative words ratio

# %%
# plotting positive and negative words ratios against each other 
sentiment_r = sns.lineplot(x="year",y="positive_words_ratio", data=df2)
sentiment_r = sns.lineplot(x="year",y="negative_words_ratio", data=df2)
plt.show()

#timeline.set_xticklabels(rotation=90)
#plt.title("Year wise Speech Length")
#plt.ylabel("")

# %% [markdown]
# ## Sentiment analysis using VADER

# %%
#!pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/86/9e/c53e1fc61aac5ee490a6ac5e21b1ac04e55a7c2aba647bb8411c9aadf24e/vaderSentiment-3.2.1-py2.py3-none-any.whl (125kB)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.2.1

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# using polarity_scores() to obtain the polarity indices for given sentence
def sentiment_analyzer_scores(sentence):
    score = analyzer.polarity_scores(sentence)
    print("{:-<40} {}".format(sentence, str(score)))

# %%
# THIS TAKES A LONG TIME RUNNING, SO DON'T RUN IT JUST FOR FUN

# This doesn't work as well as the code below, but we might have
# to find a way to do a function that applies the VADER to
# every single row... if that isn't what we are doing below.

# applying the sentiment_analyzer function
vader_sent = df2['Speech'].apply(sentiment_analyzer_scores)

# %%
# THIS TAKES A LONG TIME RUNNING, SO DON'T RUN IT JUST FOR FUN

# applying the sentiment_analyzer function
vader_sent = df2['Speech'].apply(sentiment_analyzer_scores)

# %%
vader_sent_df1 = pd.DataFrame(vader_sent1.tolist())
vader_sent_df1.head()
# Out:
#    compound    neg    neu    pos
# 0    0.9999  0.123  0.700  0.176
# 1    0.9999  0.111  0.716  0.173
# 2    0.9998  0.072  0.711  0.217
# 3    0.9999  0.099  0.731  0.171
# 4    1.0000  0.083  0.739  0.178

# %%
# A TRY AT THE VADER IMPLEMENTATION. DIDN'T WORK.

#def nltk_sentiment(sentence):
 #   from nltk.sentiment.vader import SentimentIntensityAnalyzer
    
 #   nltk_sentiment = SentimentIntensityAnalyzer()
 #   score = nltk_sentiment.polarity_scores(sentence)
 #   return score

# %%
#nltk_results = [nltk_sentiment(row) for row in df2]
#results_df = pd.DataFrame(nltk_results)
#text_df = pd.DataFrame(df2, columns=['Speech'])
#nltk_df = text_df.join(results_df)
#nltk_df
