# %% [markdown]
# # Feature Engineering

# %% [markdown]
# The next step is to create features from the raw text so we can train the machine learning models. The steps followed are:
#
# 1. **Text Cleaning and Preparation**: cleaning of special characters, downcasing, punctuation signs. possessive pronouns and stop words removal and lemmatization.
# 2. **Label coding**: creation of a dictionary to map each category to a code.
# 3. **Train-test split**: to test the models on unseen data.
# 4. **Text representation**: use of TF-IDF scores to represent text.

# %%
import pickle
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
import numpy as np

# %% [markdown]
# First of all we'll load the dataset:

# %%
#path_df = "/home/lnc/0. Latest News Classifier/02. Exploratory Data Analysis/News_dataset.pickle"

#with open(path_df, 'rb') as data:
#    df = pickle.load(data)

# %%
df = pd.read_csv('ml_model.csv')
# Out:
# C:\Users\ester\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0,1,2,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#21932 - 42286 drop 

df[21900:21950]
# Out:
#                  Name               Type     Party  Republican    year  \
# 21900  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21901  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21902  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21903  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21904  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21905  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21906  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21907  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21908  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21909  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21910  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21911  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21912  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21913  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21914  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21915  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21916  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21917  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21918  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21919  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21920  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21921  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21922  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21923  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21924  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21925  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21926  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21927  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21928  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21929  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21930  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21931  Woodrow Wilson  Inaugural Address  Democrat         0.0  1913.0
# 21932             NaN                NaN       NaN         NaN     NaN
# 21933             NaN                NaN       NaN         NaN     NaN
# 21934             NaN                NaN       NaN         NaN     NaN
# 21935             NaN                NaN       NaN         NaN     NaN
# 21936             NaN                NaN       NaN         NaN     NaN
# 21937             NaN                NaN       NaN         NaN     NaN
# 21938             NaN                NaN       NaN         NaN     NaN
# 21939             NaN                NaN       NaN         NaN     NaN
# 21940             NaN                NaN       NaN         NaN     NaN
# 21941             NaN                NaN       NaN         NaN     NaN
# 21942             NaN                NaN       NaN         NaN     NaN
# 21943             NaN                NaN       NaN         NaN     NaN
# 21944             NaN                NaN       NaN         NaN     NaN
# 21945             NaN                NaN       NaN         NaN     NaN
# 21946             NaN                NaN       NaN         NaN     NaN
# 21947             NaN                NaN       NaN         NaN     NaN
# 21948             NaN                NaN       NaN         NaN     NaN
# 21949             NaN                NaN       NaN         NaN     NaN
#
#        mean_word_length  word_count  some_word_count  unique_word  \
# 21900          6.279631      9260.0           6788.0        669.0
# 21901          6.279631      9260.0           6788.0        669.0
# 21902          6.279631      9260.0           6788.0        669.0
# 21903          6.279631      9260.0           6788.0        669.0
# 21904          6.279631      9260.0           6788.0        669.0
# 21905          6.279631      9260.0           6788.0        669.0
# 21906          6.279631      9260.0           6788.0        669.0
# 21907          6.279631      9260.0           6788.0        669.0
# 21908          6.279631      9260.0           6788.0        669.0
# 21909          6.279631      9260.0           6788.0        669.0
# 21910          6.279631      9260.0           6788.0        669.0
# 21911          6.279631      9260.0           6788.0        669.0
# 21912          6.279631      9260.0           6788.0        669.0
# 21913          6.279631      9260.0           6788.0        669.0
# 21914          6.279631      9260.0           6788.0        669.0
# 21915          6.279631      9260.0           6788.0        669.0
# 21916          6.279631      9260.0           6788.0        669.0
# 21917          6.279631      9260.0           6788.0        669.0
# 21918          6.279631      9260.0           6788.0        669.0
# 21919          6.279631      9260.0           6788.0        669.0
# 21920          6.279631      9260.0           6788.0        669.0
# 21921          6.279631      9260.0           6788.0        669.0
# 21922          6.279631      9260.0           6788.0        669.0
# 21923          6.279631      9260.0           6788.0        669.0
# 21924          6.279631      9260.0           6788.0        669.0
# 21925          6.279631      9260.0           6788.0        669.0
# 21926          6.279631      9260.0           6788.0        669.0
# 21927          6.279631      9260.0           6788.0        669.0
# 21928          6.279631      9260.0           6788.0        669.0
# 21929          6.279631      9260.0           6788.0        669.0
# 21930          6.279631      9260.0           6788.0        669.0
# 21931          6.279631      9260.0           6788.0        669.0
# 21932               NaN         NaN              NaN          NaN
# 21933               NaN         NaN              NaN          NaN
# 21934               NaN         NaN              NaN          NaN
# 21935               NaN         NaN              NaN          NaN
# 21936               NaN         NaN              NaN          NaN
# 21937               NaN         NaN              NaN          NaN
# 21938               NaN         NaN              NaN          NaN
# 21939               NaN         NaN              NaN          NaN
# 21940               NaN         NaN              NaN          NaN
# 21941               NaN         NaN              NaN          NaN
# 21942               NaN         NaN              NaN          NaN
# 21943               NaN         NaN              NaN          NaN
# 21944               NaN         NaN              NaN          NaN
# 21945               NaN         NaN              NaN          NaN
# 21946               NaN         NaN              NaN          NaN
# 21947               NaN         NaN              NaN          NaN
# 21948               NaN         NaN              NaN          NaN
# 21949               NaN         NaN              NaN          NaN
#
#        some_unique_word  ...  positive_words_ratio  negative_words_ratio  \
# 21900             557.0  ...              0.011344              0.009723
# 21901             557.0  ...              0.011344              0.009723
# 21902             557.0  ...              0.011344              0.009723
# 21903             557.0  ...              0.011344              0.009723
# 21904             557.0  ...              0.011344              0.009723
# 21905             557.0  ...              0.011344              0.009723
# 21906             557.0  ...              0.011344              0.009723
# 21907             557.0  ...              0.011344              0.009723
# 21908             557.0  ...              0.011344              0.009723
# 21909             557.0  ...              0.011344              0.009723
# 21910             557.0  ...              0.011344              0.009723
# 21911             557.0  ...              0.011344              0.009723
# 21912             557.0  ...              0.011344              0.009723
# 21913             557.0  ...              0.011344              0.009723
# 21914             557.0  ...              0.011344              0.009723
# 21915             557.0  ...              0.011344              0.009723
# 21916             557.0  ...              0.011344              0.009723
# 21917             557.0  ...              0.011344              0.009723
# 21918             557.0  ...              0.011344              0.009723
# 21919             557.0  ...              0.011344              0.009723
# 21920             557.0  ...              0.011344              0.009723
# 21921             557.0  ...              0.011344              0.009723
# 21922             557.0  ...              0.011344              0.009723
# 21923             557.0  ...              0.011344              0.009723
# 21924             557.0  ...              0.011344              0.009723
# 21925             557.0  ...              0.011344              0.009723
# 21926             557.0  ...              0.011344              0.009723
# 21927             557.0  ...              0.011344              0.009723
# 21928             557.0  ...              0.011344              0.009723
# 21929             557.0  ...              0.011344              0.009723
# 21930             557.0  ...              0.011344              0.009723
# 21931             557.0  ...              0.011344              0.009723
# 21932               NaN  ...                   NaN                   NaN
# 21933               NaN  ...                   NaN                   NaN
# 21934               NaN  ...                   NaN                   NaN
# 21935               NaN  ...                   NaN                   NaN
# 21936               NaN  ...                   NaN                   NaN
# 21937               NaN  ...                   NaN                   NaN
# 21938               NaN  ...                   NaN                   NaN
# 21939               NaN  ...                   NaN                   NaN
# 21940               NaN  ...                   NaN                   NaN
# 21941               NaN  ...                   NaN                   NaN
# 21942               NaN  ...                   NaN                   NaN
# 21943               NaN  ...                   NaN                   NaN
# 21944               NaN  ...                   NaN                   NaN
# 21945               NaN  ...                   NaN                   NaN
# 21946               NaN  ...                   NaN                   NaN
# 21947               NaN  ...                   NaN                   NaN
# 21948               NaN  ...                   NaN                   NaN
# 21949               NaN  ...                   NaN                   NaN
#
#       we_count war_count  i_count  \
# 21900     37.0       0.0      4.0
# 21901     37.0       0.0      4.0
# 21902     37.0       0.0      4.0
# 21903     37.0       0.0      4.0
# 21904     37.0       0.0      4.0
# 21905     37.0       0.0      4.0
# 21906     37.0       0.0      4.0
# 21907     37.0       0.0      4.0
# 21908     37.0       0.0      4.0
# 21909     37.0       0.0      4.0
# 21910     37.0       0.0      4.0
# 21911     37.0       0.0      4.0
# 21912     37.0       0.0      4.0
# 21913     37.0       0.0      4.0
# 21914     37.0       0.0      4.0
# 21915     37.0       0.0      4.0
# 21916     37.0       0.0      4.0
# 21917     37.0       0.0      4.0
# 21918     37.0       0.0      4.0
# 21919     37.0       0.0      4.0
# 21920     37.0       0.0      4.0
# 21921     37.0       0.0      4.0
# 21922     37.0       0.0      4.0
# 21923     37.0       0.0      4.0
# 21924     37.0       0.0      4.0
# 21925     37.0       0.0      4.0
# 21926     37.0       0.0      4.0
# 21927     37.0       0.0      4.0
# 21928     37.0       0.0      4.0
# 21929     37.0       0.0      4.0
# 21930     37.0       0.0      4.0
# 21931     37.0       0.0      4.0
# 21932      NaN       NaN      NaN
# 21933      NaN       NaN      NaN
# 21934      NaN       NaN      NaN
# 21935      NaN       NaN      NaN
# 21936      NaN       NaN      NaN
# 21937      NaN       NaN      NaN
# 21938      NaN       NaN      NaN
# 21939      NaN       NaN      NaN
# 21940      NaN       NaN      NaN
# 21941      NaN       NaN      NaN
# 21942      NaN       NaN      NaN
# 21943      NaN       NaN      NaN
# 21944      NaN       NaN      NaN
# 21945      NaN       NaN      NaN
# 21946      NaN       NaN      NaN
# 21947      NaN       NaN      NaN
# 21948      NaN       NaN      NaN
# 21949      NaN       NaN      NaN
#
#                                                Sentences  vader_neg  \
# 21900                    we hadnot forgotten our morals.      0.322
# 21901  we remembered well enough that we had set upa ...      0.000
# 21902  but we were very heedless and in a hurry to be...      0.000
# 21903      we have come now to the sober second thought.      0.000
# 21904  the scales of heedlessnesshave fallen from our...      0.263
# 21905  we have made up our minds to square every proc...      0.000
# 21906                  our work is a work ofrestoration.      0.000
# 21907  we have itemized with some degree of particula...      0.084
# 21908  we have studied as perhapsno other nation has ...      0.000
# 21909  nor have we studied and perfected the means by...      0.046
# 21910                       this is no sentimental duty.      0.293
# 21911  thefirm basis of government is justice, not pity.      0.000
# 21912  these are matters of justice.there can be no e...      0.064
# 21913  the first duty of law is to keep sound the soc...      0.000
# 21914  sanitary laws, pure food laws, and laws determ...      0.089
# 21915  these are some of the things we ought to do, a...      0.000
# 21916  this is the high enterprise of thenew day: to ...      0.000
# 21917  it is inconceivable that we should do this as ...      0.172
# 21918                     we shall restore, not destroy.      0.000
# 21919  we shall deal with oureconomic system as it is...      0.000
# 21920  justice, and onlyjustice, shall always be our ...      0.000
# 21921  and yet it will be no cool process of mere sci...      0.163
# 21922  the nation has beendeeply stirred, stirred by ...      0.230
# 21923  the feelings with which we face this new age o...      0.000
# 21924  we know our task to be no mere task of politic...      0.028
# 21925  this is not a day of triumph; it is a day of d...      0.203
# 21926  here muster,not the forces of party, but the f...      0.000
# 21927  men's hearts waitupon us; men's lives hang in ...      0.000
# 21928              who shall live up to the great trust?      0.000
# 21929                              who dares fail totry?      0.538
# 21930  i summon all honest men, all patriotic, all fo...      0.000
# 21931  god helping me, i will not fail them, if they ...      0.000
# 21932                                            part 1.      0.000
# 21933                        [on our foreign relations.]      0.000
# 21934  to the senate and house of representatives: th...      0.000
# 21935  the position of the united states in the moral...      0.000
# 21936  the national prosperity and power impose upon ...      0.082
# 21937  the tremendous growth of the export trade of t...      0.000
# 21938  with the development of our industries the for...      0.000
# 21939  whether we have a farseeing and wise diplomacy...      0.078
# 21940  in its foreign affairs the united states shoul...      0.000
# 21941  the intellectual, financial, and industrial in...      0.000
# 21942  a greater insistence upon justice to american ...      0.037
# 21943  with an appropriation made upon my recommendat...      0.000
# 21944  there were created divisions of latinamerican ...      0.000
# 21945  to these divisions were called from the foreig...      0.000
# 21946                   the work was highly specialized.      0.000
# 21947  the result is that where previously this gover...      0.000
# 21948  this principle of politico-geographical divisi...      0.000
# 21949  through the newly created division of informat...      0.000
#
#        vader_pos  vader_neu  vader_com
# 21900      0.000      0.678    -0.2263
# 21901      0.315      0.685     0.9136
# 21902      0.361      0.639     0.7684
# 21903      0.000      1.000     0.0000
# 21904      0.000      0.737    -0.3612
# 21905      0.133      0.867     0.6825
# 21906      0.000      1.000     0.0000
# 21907      0.102      0.815     0.5423
# 21908      0.064      0.936     0.2952
# 21909      0.157      0.797     0.6808
# 21910      0.307      0.400     0.0258
# 21911      0.468      0.532     0.6472
# 21912      0.154      0.782     0.7216
# 21913      0.000      1.000     0.0000
# 21914      0.214      0.697     0.5367
# 21915      0.046      0.954     0.0382
# 21916      0.061      0.939     0.2500
# 21917      0.000      0.828    -0.6369
# 21918      0.627      0.373     0.6187
# 21919      0.108      0.892     0.7650
# 21920      0.327      0.673     0.5267
# 21921      0.170      0.667     0.0258
# 21922      0.138      0.632    -0.4939
# 21923      0.203      0.797     0.8126
# 21924      0.000      0.972    -0.1531
# 21925      0.000      0.797    -0.3724
# 21926      0.156      0.844     0.2144
# 21927      0.128      0.872     0.4215
# 21928      0.552      0.448     0.8126
# 21929      0.000      0.462    -0.5423
# 21930      0.248      0.752     0.5106
# 21931      0.328      0.672     0.5215
# 21932      0.000      1.000     0.0000
# 21933      0.000      1.000     0.0000
# 21934      0.064      0.936     0.4215
# 21935      0.283      0.717     0.7964
# 21936      0.172      0.746     0.3400
# 21937      0.172      0.828     0.6597
# 21938      0.109      0.891     0.4215
# 21939      0.219      0.704     0.9661
# 21940      0.318      0.682     0.6808
# 21941      0.323      0.677     0.9726
# 21942      0.196      0.766     0.9911
# 21943      0.000      1.000     0.0000
# 21944      0.111      0.889     0.2500
# 21945      0.064      0.936     0.3818
# 21946      0.000      1.000     0.0000
# 21947      0.053      0.947     0.2500
# 21948      0.098      0.902     0.7269
# 21949      0.087      0.913     0.4588
#
# [50 rows x 27 columns]

# %% [markdown]
# And visualize one sample news content:

# %%
df=df.drop(df.index[21932:42286])

# %%
df.tail()
# Out:
#                  Name               Type  Republican    year  \
# 21927  Woodrow Wilson  Inaugural Address         0.0  1913.0
# 21928  Woodrow Wilson  Inaugural Address         0.0  1913.0
# 21929  Woodrow Wilson  Inaugural Address         0.0  1913.0
# 21930  Woodrow Wilson  Inaugural Address         0.0  1913.0
# 21931  Woodrow Wilson  Inaugural Address         0.0  1913.0
#
#        mean_word_length  word_count  some_word_count  unique_word  \
# 21927          6.279631      9260.0           6788.0        669.0
# 21928          6.279631      9260.0           6788.0        669.0
# 21929          6.279631      9260.0           6788.0        669.0
# 21930          6.279631      9260.0           6788.0        669.0
# 21931          6.279631      9260.0           6788.0        669.0
#
#        some_unique_word  unique_word_ratio  ...  positive_words_ratio  \
# 21927             557.0           0.072246  ...              0.011344
# 21928             557.0           0.072246  ...              0.011344
# 21929             557.0           0.072246  ...              0.011344
# 21930             557.0           0.072246  ...              0.011344
# 21931             557.0           0.072246  ...              0.011344
#
#       negative_words_ratio we_count  war_count  i_count  \
# 21927             0.009723     37.0        0.0      4.0
# 21928             0.009723     37.0        0.0      4.0
# 21929             0.009723     37.0        0.0      4.0
# 21930             0.009723     37.0        0.0      4.0
# 21931             0.009723     37.0        0.0      4.0
#
#                                                Sentences  vader_neg  \
# 21927  men's hearts waitupon us; men's lives hang in ...      0.000
# 21928              who shall live up to the great trust?      0.000
# 21929                              who dares fail totry?      0.538
# 21930  i summon all honest men, all patriotic, all fo...      0.000
# 21931  god helping me, i will not fail them, if they ...      0.000
#
#        vader_pos  vader_neu  vader_com
# 21927      0.128      0.872     0.4215
# 21928      0.552      0.448     0.8126
# 21929      0.000      0.462    -0.5423
# 21930      0.248      0.752     0.5106
# 21931      0.328      0.672     0.5215
#
# [5 rows x 26 columns]

# %%
# Saving the lemmatizer into an object
wordnet_lemmatizer = WordNetLemmatizer()

# %%
df.head(1)
# Out:
#            Name                Type  Republican    year  mean_word_length  \
# 0  Donald Trump  State of the Union         1.0  2019.0           6.01407
#
#    word_count  some_word_count  unique_word  some_unique_word  \
# 0     29897.0          22255.0       1659.0            1387.0
#
#    unique_word_ratio  ...  negative_words_ratio we_count war_count  i_count  \
# 0           0.055491  ...              0.007953    114.0       6.0     41.0
#
#                                            Sentences  vader_neg  vader_pos  \
# 0        madam speaker, mr. vice president, membe...        0.0      0.097
#
#    vader_neu  vader_com  Category_Code
# 0      0.903     0.4215            1.0
#
# [1 rows x 27 columns]

# %%
list_columns = ['Name', 'Type', 'Republican', 'year', 'mean_word_length',
       'word_count', 'some_word_count', 'unique_word', 'some_unique_word',
       'unique_word_ratio', 'some_unique_word_ratio', 'words', 'sentences',
       'mean_sentence_length', 'positive_words', 'negative_words',
       'positive_words_ratio', 'negative_words_ratio', 'we_count', 'war_count',
       'i_count', 'Sentences', 'vader_neg', 'vader_pos', 'vader_neu',
       'vader_com']
df = df[list_columns]

df = df.rename(columns={'Speech_Parsed_6': 'Speech_Parsed'})

# %%
df.columns
# Out:
# Index(['Name', 'Type', 'Party', 'Republican', 'year', 'mean_word_length',
#        'word_count', 'some_word_count', 'unique_word', 'some_unique_word',
#        'unique_word_ratio', 'some_unique_word_ratio', 'words', 'sentences',
#        'mean_sentence_length', 'positive_words', 'negative_words',
#        'positive_words_ratio', 'negative_words_ratio', 'we_count', 'war_count',
#        'i_count', 'Sentences', 'vader_neg', 'vader_pos', 'vader_neu',
#        'vader_com'],
#       dtype='object')

# %% [markdown]
# **IMPORTANT:**
#
# We need to remember that our model will gather the latest news articles from different newspapers every time we want. For that reason, we not only need to take into account the peculiarities of the training set articles, but also possible ones that are present in the gathered news articles.
#
# For this reason, possible peculiarities have been studied in the *05. News Scraping* folder.

# %% [markdown]
# ## 2. Label coding

# %% [markdown]
# We'll create a dictionary with the label codification:

# %%
#Republican = {
#    'democrat': 0,
 #   'republican': 1}

# %%
# Category mapping
#df['Category_Code'] = df['Republican']
#df = df.replace({'Category_Code':Republican})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-553e7b188cec> in <module>()
#       1 # Category mapping
#       2 df['Category_Code'] = df['Republican']
# ----> 3 df = df.replace({'Category_Code':Republican})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4040                                               value=value, inplace=inplace,
#    4041                                               limit=limit, regex=regex,
# -> 4042                                               method=method)
#    4043
#    4044     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6496
#    6497             return self.replace(to_replace, value, inplace=inplace,
# -> 6498                                 limit=limit, regex=regex)
#    6499         else:
#    6500
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4040                                               value=value, inplace=inplace,
#    4041                                               limit=limit, regex=regex,
# -> 4042                                               method=method)
#    4043
#    4044     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6515                                                     value=value[c],
#    6516                                                     inplace=False,
# -> 6517                                                     regex=regex)
#    6518                     return None if inplace else res
#    6519
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3843         return super(Series, self).replace(to_replace=to_replace, value=value,
#    3844                                            inplace=inplace, limit=limit,
# -> 3845                                            regex=regex, method=method)
#    3846
#    3847     @Appender(generic._shared_docs['shift'] % _shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6545                                                        dest_list=value,
#    6546                                                        inplace=inplace,
# -> 6547                                                        regex=regex)
#    6548
#    6549                 else:  # [NA, ''] -> 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     557             return _compare_or_regex_search(values, s, regex)
#     558
# --> 559         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     560
#     561         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     557             return _compare_or_regex_search(values, s, regex)
#     558
# --> 559         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     560
#     561         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in comp(s, regex)
#     555                 return _compare_or_regex_search(maybe_convert_objects(values),
#     556                                                 getattr(s, 'asm8'), regex)
# --> 557             return _compare_or_regex_search(values, s, regex)
#     558
#     559         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _compare_or_regex_search(a, b, regex)
#    1949         raise TypeError(
#    1950             "Cannot compare types {a!r} and {b!r}".format(a=type_names[0],
# -> 1951                                                           b=type_names[1]))
#    1952     return result
#    1953
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'str'

# %%
df.head()
# Out:
#            Name                Type  Republican    year  mean_word_length  \
# 0  Donald Trump  State of the Union         1.0  2019.0           6.01407
# 1  Donald Trump  State of the Union         1.0  2019.0           6.01407
# 2  Donald Trump  State of the Union         1.0  2019.0           6.01407
# 3  Donald Trump  State of the Union         1.0  2019.0           6.01407
# 4  Donald Trump  State of the Union         1.0  2019.0           6.01407
#
#    word_count  some_word_count  unique_word  some_unique_word  \
# 0     29897.0          22255.0       1659.0            1387.0
# 1     29897.0          22255.0       1659.0            1387.0
# 2     29897.0          22255.0       1659.0            1387.0
# 3     29897.0          22255.0       1659.0            1387.0
# 4     29897.0          22255.0       1659.0            1387.0
#
#    unique_word_ratio  ...  negative_words_ratio we_count war_count  i_count  \
# 0           0.055491  ...              0.007953    114.0       6.0     41.0
# 1           0.055491  ...              0.007953    114.0       6.0     41.0
# 2           0.055491  ...              0.007953    114.0       6.0     41.0
# 3           0.055491  ...              0.007953    114.0       6.0     41.0
# 4           0.055491  ...              0.007953    114.0       6.0     41.0
#
#                                            Sentences  vader_neg  vader_pos  \
# 0        madam speaker, mr. vice president, membe...      0.000      0.097
# 1  as we begin a new congress, i stand here ready...      0.000      0.122
# 2  millions of our fellow citizens are watching u...      0.053      0.159
# 3  the agenda i will lay out this evening is not ...      0.000      0.000
# 4           it is the agenda of the american people.      0.000      0.000
#
#    vader_neu  vader_com  Category_Code
# 0      0.903     0.4215            1.0
# 1      0.878     0.3612            1.0
# 2      0.788     0.4954            1.0
# 3      1.000     0.0000            1.0
# 4      1.000     0.0000            1.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 3. Train - test split

# %% [markdown]
# We'll set apart a test set to prove the quality of our models. We'll do Cross Validation in the train set in order to tune the hyperparameters and then test performance on the unseen data of the test set.

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Sentences'], 
                                                    df['Republican'], 
                                                    test_size=0.3, 
                                                    random_state=8)

# %% [markdown]
# We have 21,000 observations. we choose a test set size of 30% of the full dataset.

# %% [markdown]
# ## 4. Text representation

# %% [markdown]
# We have various options:
#
# * Count Vectors as features
# * TF-IDF Vectors as features
# * Word Embeddings as features
# * Text / NLP based features
# * Topic Models as features

# %% [markdown]
# We'll use **TF-IDF Vectors** as features.

# %% [markdown]
# We have to define the different parameters:
#
# * `ngram_range`: We want to consider both unigrams and bigrams.
# * `max_df`: When building the vocabulary ignore terms that have a document
#     frequency strictly higher than the given threshold
# * `min_df`: When building the vocabulary ignore terms that have a document
#     frequency strictly lower than the given threshold.
# * `max_features`: If not None, build a vocabulary that only consider the top
#     max_features ordered by term frequency across the corpus.
#
# See `TfidfVectorizer?` for further detail.

# %% [markdown]
# It needs to be mentioned that we are implicitly scaling our data when representing it as TF-IDF features with the argument `norm`.

# %%
# Parameter election
ngram_range = (1,2)
min_df = 10
max_df = 1.
max_features = 100

# %% [markdown]
# We have chosen these values as a first approximation. Since the models that we develop later have a very good predictive power, we'll stick to these values. But it has to be mentioned that different combinations could be tried in order to improve even more the accuracy of the models.

# %%
tfidf = TfidfVectorizer(encoding='utf-8',
                        ngram_range=ngram_range,
                        stop_words=None,
                        lowercase=False,
                        max_df=max_df,
                        min_df=min_df,
                        max_features=max_features,
                        norm='l2',
                        sublinear_tf=True)
                        
features_train = tfidf.fit_transform(X_train).toarray()
labels_train = y_train
print(features_train.shape)

features_test = tfidf.transform(X_test).toarray()
labels_test = y_test
print(features_test.shape)
# Out:
# (15352, 100)
# (6580, 100)

# %% [markdown]
# Please note that we have fitted and then transformed the training set, but we have **only transformed** the **test set**.

# %% [markdown]
# We can use the Chi squared test in order to see what unigrams and bigrams are most correlated with each category:

# %%
from sklearn.feature_selection import chi2
import numpy as np

for speech, party in sorted(df['Republican'].items()):
    features_chi2 = chi2(features_train, labels_train == party)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}' category:".format(speech))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-5:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-2:])))
    print("")
# Out:
# # '0' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '1' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '2' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '3' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '5' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '6' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '7' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '8' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '9' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '10' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '11' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '12' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '13' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '14' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '15' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '16' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '17' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '18' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '19' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '20' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '21' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '22' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '23' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '24' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '25' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '26' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '27' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '28' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '29' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '30' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '31' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '32' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '33' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '34' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '35' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '36' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '37' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '38' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '39' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '40' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '41' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '42' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '43' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '44' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '45' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '46' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '47' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '48' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '49' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '50' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '51' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '52' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '53' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '54' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '55' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '56' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '57' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '58' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '59' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '60' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '61' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '62' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '63' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '64' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# # '65' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '66' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '67' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '68' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '69' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '70' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '71' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '72' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '73' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '74' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '75' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '76' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '77' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '78' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '79' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '80' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '81' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '82' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '83' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '84' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '85' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '86' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '87' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '88' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '89' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '90' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '91' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '92' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '93' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '94' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '95' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '96' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '97' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '98' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '99' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '100' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '101' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '102' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '103' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '104' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '105' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '106' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '107' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '108' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '109' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '110' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '111' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '112' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '113' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '114' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '115' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '116' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '117' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '118' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '119' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '120' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '121' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '122' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '123' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '124' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '125' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '126' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '127' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '128' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '129' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '130' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '131' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '132' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '133' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '134' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '135' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '136' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '137' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '138' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '139' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '140' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '141' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '142' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '143' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '144' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '145' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '146' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '147' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '148' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '149' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '150' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '151' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '152' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '153' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '154' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '155' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '156' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '157' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '158' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '159' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '160' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '161' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '162' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '163' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '164' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '165' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '166' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '167' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '168' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '169' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '170' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '171' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '172' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '173' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '174' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '175' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '176' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '177' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '178' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '179' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '180' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '181' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '182' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '183' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '184' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '185' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '186' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '187' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '188' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '189' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '190' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '191' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '192' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '193' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# # '194' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '195' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '196' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '197' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '198' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '199' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '200' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '201' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '202' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '203' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '204' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '205' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '206' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '207' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '208' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '209' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '210' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '211' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '212' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '213' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '214' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '215' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '216' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '217' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '218' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '219' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '220' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '221' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '222' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '223' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '224' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '225' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '226' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '227' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '228' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '229' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '230' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '231' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '232' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '233' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '234' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '235' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '236' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '237' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '238' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '239' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '240' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '241' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '242' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '243' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '244' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '245' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '246' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '247' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '248' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '249' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '250' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '251' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '252' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '253' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '254' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '255' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '256' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '257' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# # '258' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '259' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '260' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '261' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '262' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '263' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '264' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '265' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '266' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '267' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '268' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '269' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '270' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '271' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '272' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '273' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '274' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '275' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '276' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '277' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '278' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '279' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '280' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '281' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '282' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '283' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '284' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '285' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '286' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '287' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '288' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '289' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '290' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '291' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '292' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '293' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '294' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '295' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '296' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '297' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '298' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '299' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '300' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '301' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '302' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '303' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '304' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '305' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '306' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '307' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '308' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '309' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '310' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '311' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '312' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '313' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '314' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '315' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '316' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '317' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '318' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '319' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '320' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '321' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '322' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '323' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# # '324' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '325' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '326' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '327' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '328' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '329' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '330' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '331' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '332' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '333' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '334' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '335' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '336' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '337' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '338' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '339' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '340' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '341' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '342' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '343' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '344' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '345' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '346' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '347' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '348' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '349' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '350' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '351' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '352' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '353' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '354' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '355' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '356' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '357' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '358' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '359' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '360' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '361' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
# ...
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4665' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4666' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4667' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4668' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4669' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4670' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4671' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4672' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4673' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4674' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4675' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4676' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4677' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4678' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4679' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4680' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4681' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4682' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4683' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4684' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4685' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4686' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4687' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4688' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4689' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4690' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4691' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4692' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4693' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4694' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4695' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4696' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4697' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4698' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4699' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4700' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# # '4701' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4702' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4703' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4704' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4705' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4706' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4707' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4708' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4709' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4710' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4711' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4712' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4713' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4714' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4715' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4716' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4717' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4718' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4719' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4720' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4721' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4722' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4723' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4724' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4725' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4726' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4727' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4728' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4729' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4730' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4731' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4732' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4733' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4734' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4735' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4736' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4737' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4738' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4739' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4740' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4741' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4742' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4743' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4744' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4745' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4746' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4747' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4748' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4749' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4750' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4751' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4752' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4753' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4754' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4755' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4756' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4757' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4758' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4759' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4760' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4761' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4762' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4763' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# # '4764' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4765' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4766' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4767' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4768' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4769' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4770' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4771' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4772' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4773' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
#
# # '4774' category:
#   . Most correlated unigrams:
# . do
# . which
# . 000
# . government
# . of
#   . Most correlated bigrams:
# . to the
# . of the
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-428010a7479c> in <module>()
#       3
#       4 for speech, party in sorted(df['Republican'].items()):
# ----> 5     features_chi2 = chi2(features_train, labels_train == party)
#       6     indices = np.argsort(features_chi2[0])
#       7     feature_names = np.array(tfidf.get_feature_names())[indices]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\univariate_selection.py in chi2(X, y)
#     222     observed = safe_sparse_dot(Y.T, X)          # n_classes * n_features
#     223
# --> 224     feature_count = X.sum(axis=0).reshape(1, -1)
#     225     class_prob = Y.mean(axis=0).reshape(1, -1)
#     226     expected = np.dot(class_prob.T, feature_count)
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %% [markdown]
# As we can see, the unigrams correspond well to their category. However, bigrams do not. If we get the bigrams in our features:

# %%
bigrams

# %% [markdown]
# We can see there are only six. This means the unigrams have more correlation with the category than the bigrams, and since we're restricting the number of features to the most representative 300, only a few bigrams are being considered.

# %% [markdown]
# Let's save the files we'll need in the next steps:

# %%
# X_train
with open('Pickles/X_train.pickle', 'wb') as output:
    pickle.dump(X_train, output)
    
# X_test    
with open('Pickles/X_test.pickle', 'wb') as output:
    pickle.dump(X_test, output)
    
# y_train
with open('Pickles/y_train.pickle', 'wb') as output:
    pickle.dump(y_train, output)
    
# y_test
with open('Pickles/y_test.pickle', 'wb') as output:
    pickle.dump(y_test, output)
    
# df
with open('Pickles/df.pickle', 'wb') as output:
    pickle.dump(df, output)
    
# features_train
with open('Pickles/features_train.pickle', 'wb') as output:
    pickle.dump(features_train, output)

# labels_train
with open('Pickles/labels_train.pickle', 'wb') as output:
    pickle.dump(labels_train, output)

# features_test
with open('Pickles/features_test.pickle', 'wb') as output:
    pickle.dump(features_test, output)

# labels_test
with open('Pickles/labels_test.pickle', 'wb') as output:
    pickle.dump(labels_test, output)
    
# TF-IDF object
with open('Pickles/tfidf.pickle', 'wb') as output:
    pickle.dump(tfidf, output)
