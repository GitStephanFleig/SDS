# %% [markdown]
# # Feature Engineering

# %% [markdown]
# The next step is to create features from the raw text so we can train the machine learning models. The steps followed are:
#
# 1. **Text Cleaning and Preparation**: cleaning of special characters, downcasing, punctuation signs. possessive pronouns and stop words removal and lemmatization.
# 2. **Label coding**: creation of a dictionary to map each category to a code.
# 3. **Train-test split**: to test the models on unseen data.
# 4. **Text representation**: use of TF-IDF scores to represent text.

# %%
import pickle
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
import numpy as np

# %% [markdown]
# First of all we'll load the dataset:

# %%
#path_df = "/home/lnc/0. Latest News Classifier/02. Exploratory Data Analysis/News_dataset.pickle"

#with open(path_df, 'rb') as data:
#    df = pickle.load(data)

# %%
df = pd.read_csv('ml_model.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          Name               Date  \
# 0           0             0  Donald Trump  February 05, 2019
# 1           1             1  Donald Trump   January 30, 2018
# 2           2             2  Donald Trump   January 20, 2017
# 3           3             3  Barack Obama   January 12, 2016
# 4           4             4  Barack Obama   January 20, 2015
#
#                                               Speech                Type  \
# 0  \r\n      \r\n      \r\nMadam Speaker, Mr. Vic...  State of the Union
# 1  \r\n      \r\n      Mr. Speaker, Mr. Vice Pres...  State of the Union
# 2  \r\n      \r\n      Chief Justice Roberts, Pre...   Inaugural Address
# 3  \r\n      \r\n      Mr. Speaker, Mr. Vice Pres...  State of the Union
# 4  \r\n      \r\n      Mr. Speaker, Mr. Vice Pres...  State of the Union
#
#         Party  Republican  word_count  unique_word  unique_word_ratio  year  \
# 0  Republican           1       30948         1909           0.061684  2019
# 1  Republican           1       30540         1905           0.062377  2018
# 2  Republican           1        8551          621           0.072623  2017
# 3    Democrat           0       35410         1930           0.054504  2016
# 4    Democrat           0       40477         2067           0.051066  2015
#
#    positive_words  negative_words  positive_words_ratio  negative_words_ratio  \
# 0             226             159              0.007303              0.005138
# 1             232             132              0.007597              0.004322
# 2              77              26              0.009005              0.003041
# 3             276             145              0.007794              0.004095
# 4             299             162              0.007387              0.004002
#
#    vader_compound  vader_neg  vader_neu  vader_pos
# 0          0.9999      0.123      0.700      0.176
# 1          0.9999      0.111      0.716      0.173
# 2          0.9998      0.072      0.711      0.217
# 3          0.9999      0.099      0.731      0.171
# 4          1.0000      0.083      0.739      0.178

# %% [markdown]
# And visualize one sample news content:

# %%
df.loc[1]['Speech']
# Out:
# '\r\n      \r\n      Mr. Speaker, Mr. Vice President, Members of Congress, the First Lady of the United States, and my fellow Americans:\r\n\r\nLess than 1 year has passed since I first stood at this podium, in this majestic chamber, to speak on behalf of the American People—and to address their concerns, their hopes, and their dreams. That night, our new Administration had already taken swift action. A new tide of optimism was already sweeping across our land.\r\n\r\nEach day since, we have gone forward with a clear vision and a righteous mission—to make America great again for all Americans.\r\n\r\nOver the last year, we have made incredible progress and achieved extraordinary success. We have faced challenges we expected, and others we could never have imagined. We have shared in the heights of victory and the pains of hardship. We endured floods and fires and storms. But through it all, we have seen the beauty of America’s soul, and the steel in America’s spine.\r\n\r\nEach test has forged new American heroes to remind us who we are, and show us what we can be.\r\n\r\nWe saw the volunteers of the “Cajun Navy,” racing to the rescue with their fishing boats to save people in the aftermath of a devastating hurricane.\r\n\r\nWe saw strangers shielding strangers from a hail of gunfire on the Las Vegas strip.\r\n\r\nWe heard tales of Americans like Coast Guard Petty Officer Ashlee Leppert, who is here tonight in the gallery with Melania. Ashlee was aboard one of the first helicopters on the scene in Houston during Hurricane Harvey. Through 18 hours of wind and rain, Ashlee braved live power lines and deep water, to help save more than 40 lives. Thank you, Ashlee.\r\n\r\nWe heard about Americans like firefighter David Dahlberg. He is here with us too. David faced down walls of flame to rescue almost 60 children trapped at a California summer camp threatened by wildfires.\r\n\r\nTo everyone still recovering in Texas, Florida, Louisiana, Puerto Rico, the Virgin Islands, California, and everywhere else—we are with you, we love you, and we will pull through together.\r\n\r\nSome trials over the past year touched this chamber very personally. With us tonight is one of the toughest people ever to serve in this House—a guy who took a bullet, almost died, and was back to work three and a half months later: the legend from Louisiana, Congressman Steve Scalise.\r\n\r\nWe are incredibly grateful for the heroic efforts of the Capitol Police Officers, the Alexandria Police, and the doctors, nurses, and paramedics who saved his life, and the lives of many others in this room.\r\n\r\nIn the aftermath of that terrible shooting, we came together, not as Republicans or Democrats, but as representatives of the people. But it is not enough to come together only in times of tragedy. Tonight, I call upon all of us to set aside our differences, to seek out common ground, and to summon the unity we need to deliver for the people we were elected to serve.\r\n\r\nOver the last year, the world has seen what we always knew: that no people on Earth are so fearless, or daring, or determined as Americans. If there is a mountain, we climb it. If there is a frontier, we cross it. If there is a challenge, we tame it. If there is an opportunity, we seize it.\r\n\r\nSo let us begin tonight by recognizing that the state of our Union is strong because our people are strong.\r\n\r\nAnd together, we are building a safe, strong, and proud America.\r\n\r\nSince the election, we have created 2.4 million new jobs, including 200,000 new jobs in manufacturing alone. After years of wage stagnation, we are finally seeing rising wages.\r\n\r\nUnemployment claims have hit a 45-year low. African American unemployment stands at the lowest rate ever recorded, and Hispanic American unemployment has also reached the lowest levels in history.\r\n\r\nSmall business confidence is at an all-time high. The stock market has smashed one record after another, gaining $8 trillion in value. Th ...

# %% [markdown]
# ## 1. Text cleaning and preparation

# %% [markdown]
# ### 1.1. Special character cleaning
#
# We can see the following special characters:
#
# * ``\r``
# * ``\n``
# * ``\`` before possessive pronouns (`government's = government\'s`)
# * ``\`` before possessive pronouns 2 (`Yukos'` = `Yukos\'`)
# * ``"`` when quoting text

# %%
# \r and \n
df['Speech_Parsed_1'] = df['Speech'].str.replace("\r", " ")
df['Speech_Parsed_1'] = df['Speech_Parsed_1'].str.replace("\n", " ")
df['Speech_Parsed_1'] = df['Speech_Parsed_1'].str.replace("    ", " ")

# %% [markdown]
# Regarding 3rd and 4th bullet, although it seems there is a special character, it won't affect us since it is not a *real* character:

# %%
text = "Mr Greenspan\'s"
text
# Out:
# "Mr Greenspan's"

# %%
# " when quoting text
df['Speech_Parsed_1'] = df['Speech_Parsed_1'].str.replace('"', '')

# %% [markdown]
# ### 1.2. Upcase/downcase

# %% [markdown]
# We'll downcase the texts because we want, for example, `Football` and `football` to be the same word.

# %%
# Lowercasing the text
df['Speech_Parsed_2'] = df['Speech_Parsed_1'].str.lower()

# %% [markdown]
# ### 1.3. Punctuation signs

# %% [markdown]
# Punctuation signs won't have any predicting power, so we'll just get rid of them.

# %%
punctuation_signs = list("?:!.,;")
df['Speech_Parsed_3'] = df['Speech_Parsed_2']

for punct_sign in punctuation_signs:
    df['Speech_Parsed_3'] = df['Speech_Parsed_3'].str.replace(punct_sign, '')

# %% [markdown]
# By doing this we are messing up with some numbers, but it's no problem since we aren't expecting any predicting power from them.

# %% [markdown]
# ### 1.4. Possessive pronouns

# %% [markdown]
# We'll also remove possessive pronoun terminations:

# %%
df['Speech_Parsed_4'] = df['Speech_Parsed_3'].str.replace("'s", "")

# %% [markdown]
# ### 1.5. Stemming and Lemmatization
#
# Since stemming can produce output words that don't exist, we'll only use a lemmatization process at this moment. Lemmatization takes into consideration the morphological analysis of the words and returns words that do exist, so it will be more useful for us.

# %%
# Downloading punkt and wordnet from NLTK
#nltk.download('punkt')
#print("------------------------------------------------------------")
#nltk.download('wordnet')
# Out:
# ------------------------------------------------------------
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sarah\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
# Saving the lemmatizer into an object
wordnet_lemmatizer = WordNetLemmatizer()

# %% [markdown]
# In order to lemmatize, we have to iterate through every word:

# %%
nrows = len(df)
lemmatized_text_list = []

for row in range(0, nrows):
    
    # Create an empty list containing lemmatized words
    lemmatized_list = []
    
    # Save the text and its words into an object
    text = df.loc[row]['Speech_Parsed_4']
    text_words = text.split(" ")

    # Iterate through every word to lemmatize
    for word in text_words:
        lemmatized_list.append(wordnet_lemmatizer.lemmatize(word, pos="v"))
        
    # Join the list
    lemmatized_text = " ".join(lemmatized_list)
    
    # Append to the list containing the texts
    lemmatized_text_list.append(lemmatized_text)

# %%
df['Speech_Parsed_5'] = lemmatized_text_list

# %% [markdown]
# Although lemmatization doesn't work perfectly in all cases (as can be seen in the example below), it can be useful.

# %% [markdown]
# ### 1.6. Stop words

# %%
# Downloading the stop words list
#nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sarah\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
# Loading the stop words in english
stop_words = list(stopwords.words('english'))

# %%
stop_words[0:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %% [markdown]
# To remove the stop words, we'll handle a regular expression only detecting whole words, as seen in the following example:

# %%
example = "me eating a meal"
word = "me"

# The regular expression is:
regex = r"\b" + word + r"\b"  # we need to build it like that to work properly

re.sub(regex, "StopWord", example)
# Out:
# 'StopWord eating a meal'

# %% [markdown]
# We can now loop through all the stop words:

# %%
df['Speech_Parsed_6'] = df['Speech_Parsed_5']

for stop_word in stop_words:

    regex_stopword = r"\b" + stop_word + r"\b"
    df['Speech_Parsed_6'] = df['Speech_Parsed_6'].str.replace(regex_stopword, '')

# %% [markdown]
# We have some dobule/triple spaces between words because of the replacements. However, it's not a problem because we'll tokenize by the spaces later.

# %% [markdown]
# As an example, we'll show an original news article and its modifications throughout the process:

# %%
df.loc[5]['Speech']
# Out:
# '\r\n      \r\n      Mr. Speaker, Mr. Vice President, Members of Congress, my fellow Americans:\r\n\r\nToday in America, a teacher spent extra time with a student who needed it, and did her part to lift America’s graduation rate to its highest level in more than three decades.\r\n\r\nAn entrepreneur flipped on the lights in her tech startup, and did her part to add to the more than eight million new jobs our businesses have created over the past four years. \r\n\r\nAn autoworker fine-tuned some of the best, most fuel-efficient cars in the world, and did his part to help America wean itself off foreign oil.\r\n\r\nA farmer prepared for the spring after the strongest five-year stretch of farm exports in our history.  A rural doctor gave a young child the first prescription to treat asthma that his mother could afford.  A man took the bus home from the graveyard shift, bone-tired but dreaming big dreams for his son.  And in tight-knit communities across America, fathers and mothers will tuck in their kids, put an arm around their spouse, remember fallen comrades, and give thanks for being home from a war that, after twelve long years, is finally coming to an end.\r\n\r\nTonight, this chamber speaks with one voice to the people we represent: it is you, our citizens, who make the state of our union strong.\r\n\r\n Here are the results of your efforts:  The lowest unemployment rate in over five years.  A rebounding housing market.  A manufacturing sector that’s adding jobs for the first time since the 1990s.  More oil produced at home than we buy from the rest of the world – the first time that’s happened in nearly twenty years.  Our deficits – cut by more than half.  And for the first time in over a decade, business leaders around the world have declared that China is no longer the world’s number one place to invest; America is.\r\n\r\nThat’s why I believe this can be a breakthrough year for America.  After five years of grit and determined effort, the United States is better-positioned for the 21st century than any other nation on Earth.\r\n\r\nThe question for everyone in this chamber, running through every decision we make this year, is whether we are going to help or hinder this progress.  For several years now, this town has been consumed by a rancorous argument over the proper size of the federal government.  It’s an important debate – one that dates back to our very founding.  But when that debate prevents us from carrying out even the most basic functions of our democracy – when our differences shut down government or threaten the full faith and credit of the United States – then we are not doing right by the American people.\r\n\r\nAs President, I’m committed to making Washington work better, and rebuilding the trust of the people who sent us here.  I believe most of you are, too.  Last month, thanks to the work of Democrats and Republicans, this Congress finally produced a budget that undoes some of last year’s severe cuts to priorities like education.  Nobody got everything they wanted, and we can still do more to invest in this country’s future while bringing down our deficit in a balanced way.  But the budget compromise should leave us freer to focus on creating new jobs, not creating new crises.\r\n\r\nIn the coming months, let’s see where else we can make progress together.  Let’s make this a year of action.  That’s what most Americans want – for all of us in this chamber to focus on their lives, their hopes, their aspirations.  And what I believe unites the people of this nation, regardless of race or region or party, young or old, rich or poor, is the simple, profound belief in opportunity for all – the notion that if you work hard and take responsibility, you can get ahead.\r\n\r\nLet’s face it: that belief has suffered some serious blows.  Over more than three decades, even before the Great Recession hit, massive shifts in technology and global competition had eliminated a lot of good, middle-class jobs, and weak ...

# %% [markdown]
# 1. Special character cleaning

# %%
df.loc[5]['Speech_Parsed_1']
# Out:
# '    Mr. Speaker, Mr. Vice President, Members of Congress, my fellow Americans: Today in America, a teacher spent extra time with a student who needed it, and did her part to lift America’s graduation rate to its highest level in more than three decades. An entrepreneur flipped on the lights in her tech startup, and did her part to add to the more than eight million new jobs our businesses have created over the past four years.  An autoworker fine-tuned some of the best, most fuel-efficient cars in the world, and did his part to help America wean itself off foreign oil. A farmer prepared for the spring after the strongest five-year stretch of farm exports in our history.  A rural doctor gave a young child the first prescription to treat asthma that his mother could afford.  A man took the bus home from the graveyard shift, bone-tired but dreaming big dreams for his son.  And in tight-knit communities across America, fathers and mothers will tuck in their kids, put an arm around their spouse, remember fallen comrades, and give thanks for being home from a war that, after twelve long years, is finally coming to an end. Tonight, this chamber speaks with one voice to the people we represent: it is you, our citizens, who make the state of our union strong.  Here are the results of your efforts:  The lowest unemployment rate in over five years.  A rebounding housing market.  A manufacturing sector that’s adding jobs for the first time since the 1990s.  More oil produced at home than we buy from the rest of the world – the first time that’s happened in nearly twenty years.  Our deficits – cut by more than half.  And for the first time in over a decade, business leaders around the world have declared that China is no longer the world’s number one place to invest; America is. That’s why I believe this can be a breakthrough year for America.  After five years of grit and determined effort, the United States is better-positioned for the 21st century than any other nation on Earth. The question for everyone in this chamber, running through every decision we make this year, is whether we are going to help or hinder this progress.  For several years now, this town has been consumed by a rancorous argument over the proper size of the federal government.  It’s an important debate – one that dates back to our very founding.  But when that debate prevents us from carrying out even the most basic functions of our democracy – when our differences shut down government or threaten the full faith and credit of the United States – then we are not doing right by the American people. As President, I’m committed to making Washington work better, and rebuilding the trust of the people who sent us here.  I believe most of you are, too.  Last month, thanks to the work of Democrats and Republicans, this Congress finally produced a budget that undoes some of last year’s severe cuts to priorities like education.  Nobody got everything they wanted, and we can still do more to invest in this country’s future while bringing down our deficit in a balanced way.  But the budget compromise should leave us freer to focus on creating new jobs, not creating new crises. In the coming months, let’s see where else we can make progress together.  Let’s make this a year of action.  That’s what most Americans want – for all of us in this chamber to focus on their lives, their hopes, their aspirations.  And what I believe unites the people of this nation, regardless of race or region or party, young or old, rich or poor, is the simple, profound belief in opportunity for all – the notion that if you work hard and take responsibility, you can get ahead. Let’s face it: that belief has suffered some serious blows.  Over more than three decades, even before the Great Recession hit, massive shifts in technology and global competition had eliminated a lot of good, middle-class jobs, and weakened the economic foundations that families depend on. Today, after four years of economic gr ...

# %% [markdown]
# 2. Upcase/downcase

# %%
df.loc[5]['Speech_Parsed_2']
# Out:
# '    mr. speaker, mr. vice president, members of congress, my fellow americans: today in america, a teacher spent extra time with a student who needed it, and did her part to lift america’s graduation rate to its highest level in more than three decades. an entrepreneur flipped on the lights in her tech startup, and did her part to add to the more than eight million new jobs our businesses have created over the past four years.  an autoworker fine-tuned some of the best, most fuel-efficient cars in the world, and did his part to help america wean itself off foreign oil. a farmer prepared for the spring after the strongest five-year stretch of farm exports in our history.  a rural doctor gave a young child the first prescription to treat asthma that his mother could afford.  a man took the bus home from the graveyard shift, bone-tired but dreaming big dreams for his son.  and in tight-knit communities across america, fathers and mothers will tuck in their kids, put an arm around their spouse, remember fallen comrades, and give thanks for being home from a war that, after twelve long years, is finally coming to an end. tonight, this chamber speaks with one voice to the people we represent: it is you, our citizens, who make the state of our union strong.  here are the results of your efforts:  the lowest unemployment rate in over five years.  a rebounding housing market.  a manufacturing sector that’s adding jobs for the first time since the 1990s.  more oil produced at home than we buy from the rest of the world – the first time that’s happened in nearly twenty years.  our deficits – cut by more than half.  and for the first time in over a decade, business leaders around the world have declared that china is no longer the world’s number one place to invest; america is. that’s why i believe this can be a breakthrough year for america.  after five years of grit and determined effort, the united states is better-positioned for the 21st century than any other nation on earth. the question for everyone in this chamber, running through every decision we make this year, is whether we are going to help or hinder this progress.  for several years now, this town has been consumed by a rancorous argument over the proper size of the federal government.  it’s an important debate – one that dates back to our very founding.  but when that debate prevents us from carrying out even the most basic functions of our democracy – when our differences shut down government or threaten the full faith and credit of the united states – then we are not doing right by the american people. as president, i’m committed to making washington work better, and rebuilding the trust of the people who sent us here.  i believe most of you are, too.  last month, thanks to the work of democrats and republicans, this congress finally produced a budget that undoes some of last year’s severe cuts to priorities like education.  nobody got everything they wanted, and we can still do more to invest in this country’s future while bringing down our deficit in a balanced way.  but the budget compromise should leave us freer to focus on creating new jobs, not creating new crises. in the coming months, let’s see where else we can make progress together.  let’s make this a year of action.  that’s what most americans want – for all of us in this chamber to focus on their lives, their hopes, their aspirations.  and what i believe unites the people of this nation, regardless of race or region or party, young or old, rich or poor, is the simple, profound belief in opportunity for all – the notion that if you work hard and take responsibility, you can get ahead. let’s face it: that belief has suffered some serious blows.  over more than three decades, even before the great recession hit, massive shifts in technology and global competition had eliminated a lot of good, middle-class jobs, and weakened the economic foundations that families depend on. today, after four years of economic gr ...

# %% [markdown]
# 3. Punctuation signs

# %%
df.loc[5]['Speech_Parsed_3']
# Out:
# '    mr speaker mr vice president members of congress my fellow americans today in america a teacher spent extra time with a student who needed it and did her part to lift america’s graduation rate to its highest level in more than three decades an entrepreneur flipped on the lights in her tech startup and did her part to add to the more than eight million new jobs our businesses have created over the past four years  an autoworker fine-tuned some of the best most fuel-efficient cars in the world and did his part to help america wean itself off foreign oil a farmer prepared for the spring after the strongest five-year stretch of farm exports in our history  a rural doctor gave a young child the first prescription to treat asthma that his mother could afford  a man took the bus home from the graveyard shift bone-tired but dreaming big dreams for his son  and in tight-knit communities across america fathers and mothers will tuck in their kids put an arm around their spouse remember fallen comrades and give thanks for being home from a war that after twelve long years is finally coming to an end tonight this chamber speaks with one voice to the people we represent it is you our citizens who make the state of our union strong  here are the results of your efforts  the lowest unemployment rate in over five years  a rebounding housing market  a manufacturing sector that’s adding jobs for the first time since the 1990s  more oil produced at home than we buy from the rest of the world – the first time that’s happened in nearly twenty years  our deficits – cut by more than half  and for the first time in over a decade business leaders around the world have declared that china is no longer the world’s number one place to invest america is that’s why i believe this can be a breakthrough year for america  after five years of grit and determined effort the united states is better-positioned for the 21st century than any other nation on earth the question for everyone in this chamber running through every decision we make this year is whether we are going to help or hinder this progress  for several years now this town has been consumed by a rancorous argument over the proper size of the federal government  it’s an important debate – one that dates back to our very founding  but when that debate prevents us from carrying out even the most basic functions of our democracy – when our differences shut down government or threaten the full faith and credit of the united states – then we are not doing right by the american people as president i’m committed to making washington work better and rebuilding the trust of the people who sent us here  i believe most of you are too  last month thanks to the work of democrats and republicans this congress finally produced a budget that undoes some of last year’s severe cuts to priorities like education  nobody got everything they wanted and we can still do more to invest in this country’s future while bringing down our deficit in a balanced way  but the budget compromise should leave us freer to focus on creating new jobs not creating new crises in the coming months let’s see where else we can make progress together  let’s make this a year of action  that’s what most americans want – for all of us in this chamber to focus on their lives their hopes their aspirations  and what i believe unites the people of this nation regardless of race or region or party young or old rich or poor is the simple profound belief in opportunity for all – the notion that if you work hard and take responsibility you can get ahead let’s face it that belief has suffered some serious blows  over more than three decades even before the great recession hit massive shifts in technology and global competition had eliminated a lot of good middle-class jobs and weakened the economic foundations that families depend on today after four years of economic growth corporate profits and stock prices have rarely been higher and those at the t ...

# %% [markdown]
# 4. Possessive pronouns

# %%
df.loc[5]['Speech_Parsed_4']
# Out:
# '    mr speaker mr vice president members of congress my fellow americans today in america a teacher spent extra time with a student who needed it and did her part to lift america’s graduation rate to its highest level in more than three decades an entrepreneur flipped on the lights in her tech startup and did her part to add to the more than eight million new jobs our businesses have created over the past four years  an autoworker fine-tuned some of the best most fuel-efficient cars in the world and did his part to help america wean itself off foreign oil a farmer prepared for the spring after the strongest five-year stretch of farm exports in our history  a rural doctor gave a young child the first prescription to treat asthma that his mother could afford  a man took the bus home from the graveyard shift bone-tired but dreaming big dreams for his son  and in tight-knit communities across america fathers and mothers will tuck in their kids put an arm around their spouse remember fallen comrades and give thanks for being home from a war that after twelve long years is finally coming to an end tonight this chamber speaks with one voice to the people we represent it is you our citizens who make the state of our union strong  here are the results of your efforts  the lowest unemployment rate in over five years  a rebounding housing market  a manufacturing sector that’s adding jobs for the first time since the 1990s  more oil produced at home than we buy from the rest of the world – the first time that’s happened in nearly twenty years  our deficits – cut by more than half  and for the first time in over a decade business leaders around the world have declared that china is no longer the world’s number one place to invest america is that’s why i believe this can be a breakthrough year for america  after five years of grit and determined effort the united states is better-positioned for the 21st century than any other nation on earth the question for everyone in this chamber running through every decision we make this year is whether we are going to help or hinder this progress  for several years now this town has been consumed by a rancorous argument over the proper size of the federal government  it’s an important debate – one that dates back to our very founding  but when that debate prevents us from carrying out even the most basic functions of our democracy – when our differences shut down government or threaten the full faith and credit of the united states – then we are not doing right by the american people as president i’m committed to making washington work better and rebuilding the trust of the people who sent us here  i believe most of you are too  last month thanks to the work of democrats and republicans this congress finally produced a budget that undoes some of last year’s severe cuts to priorities like education  nobody got everything they wanted and we can still do more to invest in this country’s future while bringing down our deficit in a balanced way  but the budget compromise should leave us freer to focus on creating new jobs not creating new crises in the coming months let’s see where else we can make progress together  let’s make this a year of action  that’s what most americans want – for all of us in this chamber to focus on their lives their hopes their aspirations  and what i believe unites the people of this nation regardless of race or region or party young or old rich or poor is the simple profound belief in opportunity for all – the notion that if you work hard and take responsibility you can get ahead let’s face it that belief has suffered some serious blows  over more than three decades even before the great recession hit massive shifts in technology and global competition had eliminated a lot of good middle-class jobs and weakened the economic foundations that families depend on today after four years of economic growth corporate profits and stock prices have rarely been higher and those at the t ...

# %% [markdown]
# 5. Stemming and Lemmatization

# %%
df.loc[5]['Speech_Parsed_5']
# Out:
# '    mr speaker mr vice president members of congress my fellow americans today in america a teacher spend extra time with a student who need it and do her part to lift america’s graduation rate to its highest level in more than three decades an entrepreneur flip on the light in her tech startup and do her part to add to the more than eight million new job our businesses have create over the past four years  an autoworker fine-tune some of the best most fuel-efficient cars in the world and do his part to help america wean itself off foreign oil a farmer prepare for the spring after the strongest five-year stretch of farm export in our history  a rural doctor give a young child the first prescription to treat asthma that his mother could afford  a man take the bus home from the graveyard shift bone-tired but dream big dream for his son  and in tight-knit communities across america father and mother will tuck in their kid put an arm around their spouse remember fall comrades and give thank for be home from a war that after twelve long years be finally come to an end tonight this chamber speak with one voice to the people we represent it be you our citizens who make the state of our union strong  here be the result of your efforts  the lowest unemployment rate in over five years  a rebound house market  a manufacture sector that’s add job for the first time since the 1990s  more oil produce at home than we buy from the rest of the world – the first time that’s happen in nearly twenty years  our deficits – cut by more than half  and for the first time in over a decade business leaders around the world have declare that china be no longer the world’s number one place to invest america be that’s why i believe this can be a breakthrough year for america  after five years of grit and determine effort the unite state be better-positioned for the 21st century than any other nation on earth the question for everyone in this chamber run through every decision we make this year be whether we be go to help or hinder this progress  for several years now this town have be consume by a rancorous argument over the proper size of the federal government  it’s an important debate – one that date back to our very found  but when that debate prevent us from carry out even the most basic function of our democracy – when our differences shut down government or threaten the full faith and credit of the unite state – then we be not do right by the american people as president i’m commit to make washington work better and rebuild the trust of the people who send us here  i believe most of you be too  last month thank to the work of democrats and republicans this congress finally produce a budget that undo some of last year’s severe cut to priorities like education  nobody get everything they want and we can still do more to invest in this country’s future while bring down our deficit in a balance way  but the budget compromise should leave us freer to focus on create new job not create new crises in the come months let’s see where else we can make progress together  let’s make this a year of action  that’s what most americans want – for all of us in this chamber to focus on their live their hop their aspirations  and what i believe unite the people of this nation regardless of race or region or party young or old rich or poor be the simple profound belief in opportunity for all – the notion that if you work hard and take responsibility you can get ahead let’s face it that belief have suffer some serious blow  over more than three decades even before the great recession hit massive shift in technology and global competition have eliminate a lot of good middle-class job and weaken the economic foundations that families depend on today after four years of economic growth corporate profit and stock price have rarely be higher and those at the top have never do better  but average wag have barely budge  inequality have deepen  upward mobility have stall  the  ...

# %% [markdown]
# 6. Stop words

# %%
df.loc[5]['Speech_Parsed_6']
# Out:
# '    mr speaker mr vice president members  congress  fellow americans today  america  teacher spend extra time   student  need     part  lift america’ graduation rate   highest level    three decades  entrepreneur flip   light   tech startup    part  add     eight million new job  businesses  create   past four years   autoworker fine-tune    best  fuel-efficient cars   world    part  help america wean   foreign oil  farmer prepare   spring   strongest five-year stretch  farm export   history   rural doctor give  young child  first prescription  treat asthma   mother could afford   man take  bus home   graveyard shift bone-tired  dream big dream   son    tight-knit communities across america father  mother  tuck   kid put  arm around  spouse remember fall comrades  give thank   home   war   twelve long years  finally come   end tonight  chamber speak  one voice   people  represent     citizens  make  state   union strong     result   efforts   lowest unemployment rate   five years   rebound house market   manufacture sector ’ add job   first time since  1990s   oil produce  home   buy   rest   world –  first time ’ happen  nearly twenty years   deficits – cut    half     first time    decade business leaders around  world  declare  china   longer  world’ number one place  invest america  ’   believe     breakthrough year  america   five years  grit  determine effort  unite state  better-positioned   21st century    nation  earth  question  everyone   chamber run  every decision  make  year  whether   go  help  hinder  progress   several years   town   consume   rancorous argument   proper size   federal government  ’  important debate – one  date back    found     debate prevent us  carry  even   basic function   democracy –   differences shut  government  threaten  full faith  credit   unite state –      right   american people  president ’ commit  make washington work better  rebuild  trust   people  send us    believe       last month thank   work  democrats  republicans  congress finally produce  budget  undo   last year’ severe cut  priorities like education  nobody get everything  want    still    invest   country’ future  bring   deficit   balance way    budget compromise  leave us freer  focus  create new job  create new crises   come months let’ see  else   make progress together  let’ make   year  action  ’   americans want –    us   chamber  focus   live  hop  aspirations     believe unite  people   nation regardless  race  region  party young  old rich  poor   simple profound belief  opportunity   –  notion    work hard  take responsibility   get ahead let’ face   belief  suffer  serious blow     three decades even   great recession hit massive shift  technology  global competition  eliminate  lot  good middle-class job  weaken  economic foundations  families depend  today  four years  economic growth corporate profit  stock price  rarely  higher     top  never  better   average wag  barely budge  inequality  deepen  upward mobility  stall   cold hard fact   even   midst  recovery  many americans  work   ever   get  – let alone get ahead    many still ’ work    job   reverse  trend   ’ happen right away   ’ agree  everything     offer tonight   set  concrete practical proposals  speed  growth strengthen  middle class  build new ladder  opportunity   middle class   require congressional action  ’ eager  work       america   stand still –  neither     wherever  whenever   take step without legislation  expand opportunity   american families ’  ’ go     usual  first lady set  good example  michelle’ let’ move partnership  school businesses  local leaders  help bring  childhood obesity rat   first time  thirty years –  achievement   improve live  reduce health care cost  decades  come   join force alliance  michelle  jill biden launch  already encourage employers  hire  train nearly 400000 veterans  military spouses  take  page   playbook  white house  organize  college opportunity summit  already 150 universities busi ...

# %% [markdown]
# Finally, we can delete the intermediate columns:

# %%
df.head(1)
# Out:
#    Unnamed: 0  Unnamed: 0.1          Name               Date  \
# 0           0             0  Donald Trump  February 05, 2019
#
#                                               Speech                Type  \
# 0  \r\n      \r\n      \r\nMadam Speaker, Mr. Vic...  State of the Union
#
#         Party  Republican  word_count  unique_word  ...  vader_compound  \
# 0  Republican           1       30948         1909  ...          0.9999
#
#    vader_neg  vader_neu  vader_pos  \
# 0      0.123        0.7      0.176
#
#                                      Speech_Parsed_1  \
# 0        Madam Speaker, Mr. Vice President, Membe...
#
#                                      Speech_Parsed_2  \
# 0        madam speaker, mr. vice president, membe...
#
#                                      Speech_Parsed_3  \
# 0        madam speaker mr vice president members ...
#
#                                      Speech_Parsed_4  \
# 0        madam speaker mr vice president members ...
#
#                                      Speech_Parsed_5  \
# 0        madam speaker mr vice president members ...
#
#                                      Speech_Parsed_6
# 0        madam speaker mr vice president members ...
#
# [1 rows x 26 columns]

# %%
list_columns = ["File_Name", "Category", "Complete_Filename", "Content", "Content_Parsed_6"]
df = df[list_columns]

df = df.rename(columns={'Speech_Parsed_6': 'Speech_Parsed'})

# %%
df.head()
# Out:
#   File_Name  Category Complete_Filename  \
# 0   001.txt  business  001.txt-business
# 1   002.txt  business  002.txt-business
# 2   003.txt  business  003.txt-business
# 3   004.txt  business  004.txt-business
# 4   005.txt  business  005.txt-business
#
#                                              Content  \
# 0  Ad sales boost Time Warner profit\r\n\r\nQuart...
# 1  Dollar gains on Greenspan speech\r\n\r\nThe do...
# 2  Yukos unit buyer faces loan claim\r\n\r\nThe o...
# 3  High fuel prices hit BA's profits\r\n\r\nBriti...
# 4  Pernod takeover talk lifts Domecq\r\n\r\nShare...
#
#                                       Content_Parsed
# 0  ad sales boost time warner profit quarterly pr...
# 1  dollar gain  greenspan speech  dollar  hit  hi...
# 2  yukos unit buyer face loan claim  owners  emba...
# 3  high fuel price hit ba profit british airways ...
# 4  pernod takeover talk lift domecq share  uk dri...

# %% [markdown]
# **IMPORTANT:**
#
# We need to remember that our model will gather the latest news articles from different newspapers every time we want. For that reason, we not only need to take into account the peculiarities of the training set articles, but also possible ones that are present in the gathered news articles.
#
# For this reason, possible peculiarities have been studied in the *05. News Scraping* folder.

# %% [markdown]
# ## 2. Label coding

# %% [markdown]
# We'll create a dictionary with the label codification:

# %%
category_codes = {
    'business': 0,
    'entertainment': 1,
    'politics': 2,
    'sport': 3,
    'tech': 4
}

# %%
# Category mapping
df['Category_Code'] = df['Category']
df = df.replace({'Category_Code':category_codes})

# %%
df.head()
# Out:
#   File_Name  Category Complete_Filename  \
# 0   001.txt  business  001.txt-business
# 1   002.txt  business  002.txt-business
# 2   003.txt  business  003.txt-business
# 3   004.txt  business  004.txt-business
# 4   005.txt  business  005.txt-business
#
#                                              Content  \
# 0  Ad sales boost Time Warner profit\r\n\r\nQuart...
# 1  Dollar gains on Greenspan speech\r\n\r\nThe do...
# 2  Yukos unit buyer faces loan claim\r\n\r\nThe o...
# 3  High fuel prices hit BA's profits\r\n\r\nBriti...
# 4  Pernod takeover talk lifts Domecq\r\n\r\nShare...
#
#                                       Content_Parsed  Category_Code
# 0  ad sales boost time warner profit quarterly pr...              0
# 1  dollar gain  greenspan speech  dollar  hit  hi...              0
# 2  yukos unit buyer face loan claim  owners  emba...              0
# 3  high fuel price hit ba profit british airways ...              0
# 4  pernod takeover talk lift domecq share  uk dri...              0

# %% [markdown]
# ## 3. Train - test split

# %% [markdown]
# We'll set apart a test set to prove the quality of our models. We'll do Cross Validation in the train set in order to tune the hyperparameters and then test performance on the unseen data of the test set.

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Speech_Parsed_6'], 
                                                    df['Republican'], 
                                                    test_size=0.15, 
                                                    random_state=8)

# %% [markdown]
# Since we don't have much observations (only 2.225), we'll choose a test set size of 15% of the full dataset.

# %% [markdown]
# ## 4. Text representation

# %% [markdown]
# We have various options:
#
# * Count Vectors as features
# * TF-IDF Vectors as features
# * Word Embeddings as features
# * Text / NLP based features
# * Topic Models as features

# %% [markdown]
# We'll use **TF-IDF Vectors** as features.

# %% [markdown]
# We have to define the different parameters:
#
# * `ngram_range`: We want to consider both unigrams and bigrams.
# * `max_df`: When building the vocabulary ignore terms that have a document
#     frequency strictly higher than the given threshold
# * `min_df`: When building the vocabulary ignore terms that have a document
#     frequency strictly lower than the given threshold.
# * `max_features`: If not None, build a vocabulary that only consider the top
#     max_features ordered by term frequency across the corpus.
#
# See `TfidfVectorizer?` for further detail.

# %% [markdown]
# It needs to be mentioned that we are implicitly scaling our data when representing it as TF-IDF features with the argument `norm`.

# %%
# Parameter election
ngram_range = (1,2)
min_df = 10
max_df = 1.
max_features = 300

# %% [markdown]
# We have chosen these values as a first approximation. Since the models that we develop later have a very good predictive power, we'll stick to these values. But it has to be mentioned that different combinations could be tried in order to improve even more the accuracy of the models.

# %%
tfidf = TfidfVectorizer(encoding='utf-8',
                        ngram_range=ngram_range,
                        stop_words=None,
                        lowercase=False,
                        max_df=max_df,
                        min_df=min_df,
                        max_features=max_features,
                        norm='l2',
                        sublinear_tf=True)
                        
features_train = tfidf.fit_transform(X_train).toarray()
labels_train = y_train
print(features_train.shape)

features_test = tfidf.transform(X_test).toarray()
labels_test = y_test
print(features_test.shape)
# Out:
# (146, 300)
# (26, 300)

# %% [markdown]
# Please note that we have fitted and then transformed the training set, but we have **only transformed** the **test set**.

# %% [markdown]
# We can use the Chi squared test in order to see what unigrams and bigrams are most correlated with each category:

# %%
from sklearn.feature_selection import chi2
import numpy as np

for speech, party in sorted(df['Republican'].items()):
    features_chi2 = chi2(features_train, labels_train == party)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}' category:".format(speech))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-5:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-2:])))
    print("")
# Out:
# # '0' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '1' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '2' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '3' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '4' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '5' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '6' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '7' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '8' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '9' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '10' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '11' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '12' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '13' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '14' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '15' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '16' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '17' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '18' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '19' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '20' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '21' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '22' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '23' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '24' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '25' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '26' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '27' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '28' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '29' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '30' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '31' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '32' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '33' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '34' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '35' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '36' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '37' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '38' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '39' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '40' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '41' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '42' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '43' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '44' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '45' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '46' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '47' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '48' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '49' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '50' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '51' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '52' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '53' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '54' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '55' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '56' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '57' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '58' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '59' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '60' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '61' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '62' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '63' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '64' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '65' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '66' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '67' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '68' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '69' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '70' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '71' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '72' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '73' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '74' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '75' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '76' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '77' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '78' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '79' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '80' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '81' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '82' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '83' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '84' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '85' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '86' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '87' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '88' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '89' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '90' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '91' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '92' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '93' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '94' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '95' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '96' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '97' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '98' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '99' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '100' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '101' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '102' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '103' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '104' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '105' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '106' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '107' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '108' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '109' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '110' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '111' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '112' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '113' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '114' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '115' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '116' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '117' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '118' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '119' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '120' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '121' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '122' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '123' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '124' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '125' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '126' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '127' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '128' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '129' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '130' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '131' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '132' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '133' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '134' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '135' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '136' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '137' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '138' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '139' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '140' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '141' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '142' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '143' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '144' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '145' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '146' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '147' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '148' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '149' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '150' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '151' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '152' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
# # '153' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '154' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '155' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '156' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '157' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '158' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '159' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '160' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '161' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '162' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '163' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '164' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '165' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '166' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '167' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '168' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '169' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '170' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent
#
# # '171' category:
#   . Most correlated unigrams:
# . cent
# . common
# . commission
# . per
# . court
#   . Most correlated bigrams:
# . unite state
# . per cent

# %% [markdown]
# As we can see, the unigrams correspond well to their category. However, bigrams do not. If we get the bigrams in our features:

# %%
bigrams
# Out:
# ['fiscal year', 'unite state', 'per cent']

# %% [markdown]
# We can see there are only six. This means the unigrams have more correlation with the category than the bigrams, and since we're restricting the number of features to the most representative 300, only a few bigrams are being considered.

# %% [markdown]
# Let's save the files we'll need in the next steps:

# %%
# X_train
with open('Pickles/X_train.pickle', 'wb') as output:
    pickle.dump(X_train, output)
    
# X_test    
with open('Pickles/X_test.pickle', 'wb') as output:
    pickle.dump(X_test, output)
    
# y_train
with open('Pickles/y_train.pickle', 'wb') as output:
    pickle.dump(y_train, output)
    
# y_test
with open('Pickles/y_test.pickle', 'wb') as output:
    pickle.dump(y_test, output)
    
# df
with open('Pickles/df.pickle', 'wb') as output:
    pickle.dump(df, output)
    
# features_train
with open('Pickles/features_train.pickle', 'wb') as output:
    pickle.dump(features_train, output)

# labels_train
with open('Pickles/labels_train.pickle', 'wb') as output:
    pickle.dump(labels_train, output)

# features_test
with open('Pickles/features_test.pickle', 'wb') as output:
    pickle.dump(features_test, output)

# labels_test
with open('Pickles/labels_test.pickle', 'wb') as output:
    pickle.dump(labels_test, output)
    
# TF-IDF object
with open('Pickles/tfidf.pickle', 'wb') as output:
    pickle.dump(tfidf, output)
