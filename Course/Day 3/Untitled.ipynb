# %%
import matplotlib.pyplot as plt
# allow printing in notebook
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns # high level plotting library

# %%
tips = sns.load_dataset('tips')
print('Number of rows:',len(tips),'\n')
print(tips.head(3))
# Out:
# Number of rows: 244
#
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tb = tips['total_bill']
cuts = np.arange(0, 100, 20) # range from 0 to 100 with 20 between
tb_cat = pd.cut(tb, cuts) # cut into categorical data
tb_cat.value_counts()
# Out:
# (0, 20]     147
# (20, 40]     87
# (40, 60]     10
# (60, 80]      0
# Name: total_bill, dtype: int64

# %%
histplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ca63bf90e212> in <module>()
# ----> 1 histplot
#
# NameError: name 'histplot' is not defined

# %%
fig, ax=plt.subplots(figsize=(6,2.5))
#fig the actual plot with is displayed (export to pdf etc.)
#ax contains most of the chart content

# %%
fig, ax=plt.subplots()
ax.set_xlim([0,60])
ax.set_ylim([0,80])
ax.hist(tb)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# What would be like to change?
# - font size, x-axis label and y-axis label
# - color, thinner

# %%
plt.style.use('ggplot') #you can use either default style or ggplot (there are many others!)
plt.rcParams['figure.figsize']=10,3
plt.rcParams.update({'font.size':18})

# %%
tb.plot()
tb.plot.hist()

# %% [markdown]
# - seaborn and panda are good for.
# - matplotlip is for customized data, so it is good for explanatary stuff
# - whereas seaborn and panda are good for fast and easy
#
# - it can be a good idea to start from seaborn and moving on to more customized

# %%
sns.distplot(tb)
sns.distplot(tb,kde=False) # If you put the kde=False afterwards e remove part of the argument

# %%
sns.distplot(tb,hist_kws={'cumulative':True},kde_kws={'cumulative':True})

# %%
sns.countplot(x='sex',data=tips)

# %%
plt.scatter(x=tips['total_bill'],y=tips['tip'])

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde', size=5)
# Out:
# C:\Users\ester\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,size=3, aspect=2.5)
#It can be a good idea to start with this kind of plots for the exam
# Out:
# C:\Users\ester\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
f=sns.barplot(x='day',y='tip',hue='sex' , data=tips)

# %%
f=sns.boxplot(x='sex',y='tip',data=tips)
f,ax=plt.subplots()
sns.boxplot(x='sex',y='tip',data=tips, ax=ax)
f.savefig('my_box.pdf')

# %%
sns.lmplot('total_bill','tip',hue='day',data=tips)

# %%
sns.pairplot(tips,height=2.3)
