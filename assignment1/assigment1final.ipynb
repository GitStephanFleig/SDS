# %% [markdown]
# # Mandatory Assignment 1
#
# This is the first of two mandatory assignments which must be completed during the course. First some practical information:
#
# * When is the assignment due?: **23:59, Sunday, August 19, 2018.**
# * How do you grade the assignment?: You will **peergrade** each other as primary grading.
# * Can i work with my group?: **yes**
#
# The assigment consist of one to tree problems from each of the exercise sets you have solved so far (excluding Set 1). We've tried to select problems which are self contained, but it might be nessecary to solve some of the previous exercises in each set to fully answer the problems in this assignment.
#
# ## Problems from Exercise Set 2:
#
# > **Ex. 2.2**: Make two lists. The first should be numbered. The second should be unnumbered and contain at least one sublevel.

# %%
# [Answer to Ex. 2.2 here] (convert to markdown cell)

# %% [markdown]
# # Numbered List
#
# 1. Item1
# 2. Item2
# 3. Item3

# %% [markdown]
# # Unnumbered list
#
# - Item1
# - Item2
#     - Item2.1
#     - Item2.3
# - Item3

# %% [markdown]
# ## Problems from Exercise set 3:
#
# > **Ex. 3.1.3:** Let `l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']`. Create from `l1` the sentence `"Is r > g?"` using your knowledge about string formatting. Store this new string in a variable called `answer_31`. Make sure there is only one space in between worlds.
# >
# >> _Hint:_ You should be able to combine the above informations to solve this exercise.

# %%
# [Answer to Ex. 3.1.3 here]
l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']

# YOUR CODE HERE
answer_31 = l1[1]+" "+l1[0].strip() +" "+l1[2].strip() +" "+l1[4].strip()+"?" 
# alternative: answer_31 = ' '.join(['Is','r','>','g'])+'?'
answer_31
# Out:
# 'Is r > g?'

# %%
assert answer_31 == "Is r > g?"

# %% [markdown]
# > **Ex. 3.1.4**: Create an empty dictionary `words` using the `dict()`function. Then add each of the words in `['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']` as a key, with the value being a boolean indicator for whether the word begins with a vowel. The results should look like `{'bacon': False, 'asynchronous': True ...}`. Store the result in a new variable called `answer_32`.
# >
# >> _Hint:_ You might want co first construct a function that asseses whether a given word begins with a vowel or not.

# %%
# [Answer to Ex. 3.1.4 here]
W = ['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']

# YOUR CODE HERE

def vowel(x):
    if x[0] in 'aeiou':
        return True 
    else:
        return False

wordlist=['animal', 'coffee', 'python','unit','knowledge','tread','arise']
vowels=[]
for i in wordlist:
    vowels.append(vowel(i))
zipped=zip(wordlist,vowels)
words=dict(zipped)
answer_32=words

# %%
assert answer_32 == {i: i[0] in 'aeiou' for i in W}
assert sorted(answer_32) == sorted(W)

# %% [markdown]
# > **Ex. 3.3.2:** use the `requests` module (get it with `pip install requests`) and `construct_link()` which you defined in the previous question (ex 3.3.1) to request birth data from the "FOD" table. Get all available years (variable "Tid"), but only female births (BARNKON=P) . Unpack the json payload and store the result. Wrap the whole thing in a function which takes an url as input and returns the corresponding output.
# >
# > Store the birth data in a new variable called `answer_33`.
# >
# >> _Hint:_ The `requests.response` object has a `.json()` method.
# >
# >> _Note:_ you wrote `construct_link()` in 3.3.1, if you didn't heres the link you need to get: `https://api.statbank.dk/v1/data/FOLK1A/JSONSTAT?lang=en&Tid=*`

# %%
# [Answer to Ex. 3.3.2 here]

import requests

# YOUR CODE HERE

dst_url = 'https://api.statbank.dk/v1/data/FOLK1A/JSONSTAT?lang=en&Tid=*'

def contruct_link(id,list):
    server_dst_url='https://api.statbank.dk/v1/data/'
    url=server_dst_url + id + '/JSONSTAT?' + '&'.join(list)
    rep=requests.get(url)
    return rep.json()
    
contruct_link('FOD',['tid=*','BARNKON=P'])

answer_33 = contruct_link('FOD',['tid=*','BARNKON=P'])
answer_33
# Out:
# {'dataset': {'dimension': {'BARNKON': {'label': 'barnets køn',
#     'category': {'index': {'P': 0}, 'label': {'P': 'Piger'}}},
#    'ContentsCode': {'label': 'Indhold',
#     'category': {'index': {'FOD': 0},
#      'label': {'FOD': 'Levendefødte'},
#      'unit': {'FOD': {'base': 'antal', 'decimals': 0}}}},
#    'Tid': {'label': 'tid',
#     'category': {'index': {'1973': 0,
#       '1974': 1,
#       '1975': 2,
#       '1976': 3,
#       '1977': 4,
#       '1978': 5,
#       '1979': 6,
#       '1980': 7,
#       '1981': 8,
#       '1982': 9,
#       '1983': 10,
#       '1984': 11,
#       '1985': 12,
#       '1986': 13,
#       '1987': 14,
#       '1988': 15,
#       '1989': 16,
#       '1990': 17,
#       '1991': 18,
#       '1992': 19,
#       '1993': 20,
#       '1994': 21,
#       '1995': 22,
#       '1996': 23,
#       '1997': 24,
#       '1998': 25,
#       '1999': 26,
#       '2000': 27,
#       '2001': 28,
#       '2002': 29,
#       '2003': 30,
#       '2004': 31,
#       '2005': 32,
#       '2006': 33,
#       '2007': 34,
#       '2008': 35,
#       '2009': 36,
#       '2010': 37,
#       '2011': 38,
#       '2012': 39,
#       '2013': 40,
#       '2014': 41,
#       '2015': 42,
#       '2016': 43,
#       '2017': 44,
#       '2018': 45},
#      'label': {'1973': '1973',
#       '1974': '1974',
#       '1975': '1975',
#       '1976': '1976',
#       '1977': '1977',
#       '1978': '1978',
#       '1979': '1979',
#       '1980': '1980',
#       '1981': '1981',
#       '1982': '1982',
#       '1983': '1983',
#       '1984': '1984',
#       '1985': '1985',
#       '1986': '1986',
#       '1987': '1987',
#       '1988': '1988',
#       '1989': '1989',
#       '1990': '1990',
#       '1991': '1991',
#       '1992': '1992',
#       '1993': '1993',
#       '1994': '1994',
#       '1995': '1995',
#       '1996': '1996',
#       '1997': '1997',
#       '1998': '1998',
#       '1999': '1999',
#       '2000': '2000',
#       '2001': '2001',
#       '2002': '2002',
#       '2003': '2003',
#       '2004': '2004',
#       '2005': '2005',
#       '2006': '2006',
#       '2007': '2007',
#       '2008': '2008',
#       '2009': '2009',
#       '2010': '2010',
#       '2011': '2011',
#       '2012': '2012',
#       '2013': '2013',
#       '2014': '2014',
#       '2015': '2015',
#       '2016': '2016',
#       '2017': '2017',
#       '2018': '2018'}}},
#    'id': ['BARNKON', 'ContentsCode', 'Tid'],
#    'size': [1, 1, 46],
#    'role': {'metric': ['ContentsCode'], 'time': ['Tid']}},
#   'label': 'Levendefødte efter barnets køn, Indhold og tid',
#   'source': 'Danmarks Statistik',
#   'updated': '2019-02-11T07:00:00Z',
#   'value': [34996,
#    34771,
#    35260,
#    31533,
#    30055,
#    30161,
#    28909,
#    27941,
#    25972,
#    25595,
#    24821,
#    25228,
#    26284,
#    26878,
#    27142,
#    28520,
#    29876,
#    30813,
#    31353,
#    32914,
#    32760,
#    34027,
#    33885,
#    32819,
#    32899,
#    32116,
#    32341,
#    32652,
#    31961,
#    31109,
#    31441,
#    31539,
#    31459,
#    31580,
#    31267,
#    31507,
#    30557,
#    30946,
#    28984,
#    28131,
#    27283,
#    27616,
#    28357,
#    29833,
#    29930,
#    29865]}}

# %%
assert sorted(answer_33['dataset'].keys()) == ['dimension', 'label', 'source', 'updated', 'value']
assert 'BARNKON' in answer_33['dataset']['dimension'].keys()

# %% [markdown]
# ## Problems from exercise set 4

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# > **Ex. 4.1.1:** Use Pandas' CSV reader to fetch  daily data weather from 1864 for various stations - available [here](https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/). Store the dataframe in a variable called `answer_41`.
# >
# >> *Hint 1*: for compressed files you may need to specify the keyword `compression`.
# >
# >> *Hint 2*: keyword `header` can be specified as the CSV has no column names.
# >
# >> *Hint 3*: Specify the path, as the URL linking directly to the 1864 file.

# %%
# [Answer to Ex. 4.1.1 here]

# YOUR CODE HERE

import pandas as pd

url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/1864.csv.gz'

answer_41 = pd.read_csv(url,compression='gzip',header=None)

# %%
answer_41.shape
# Out:
# (27349, 8)

# %%
assert answer_41.shape == (27349, 8)
assert list(answer_41.columns) == list(range(8))

# %% [markdown]
# > **Ex. 4.1.2:** Structure your weather DataFrame by using only the relevant columns (station identifier, data, observation type, observation value), rename them. Make sure observations are correctly formated (how many decimals should we add? one?).
# >
# > Store the resulting dataframe in a new variable called `answer_42`.
# >
# >> *Hint:* rename can be done with `df.columns=COLS` where `COLS` is a list of column names.

# %%
# [Answer to Ex. 4.1.2 here]

# answer_42 = 

# YOUR CODE HERE

answer_42 = answer_41.iloc[:,:4]
answer_42.columns = ['station', 'datetime', 'obs_type', 'obs_value']
answer_42['obs_value'] = answer_42['obs_value'] / 10
answer_42.head()
# Out:
#        station  datetime obs_type  obs_value
# 0  ITE00100550  18640101     TMAX        1.0
# 1  ITE00100550  18640101     TMIN       -2.3
# 2  ITE00100550  18640101     PRCP        2.5
# 3  ASN00079028  18640101     PRCP        0.0
# 4  USC00064757  18640101     PRCP       11.9

# %%
assert answer_42.shape == (27349, 4)
assert 144.8 in [answer_42[i].max() for i in answer_42]
assert -666.0 in [answer_42[i].min() for i in answer_42]
assert 18640101 in [answer_42[i].min() for i in answer_42]

# %% [markdown]
# > **Ex. 4.1.3:**  Select data for the station `ITE00100550` and only observations for maximal temperature. Make a copy of the DataFrame. Explain in a one or two sentences how copying works.
# >
# > Store the subsetted dataframe in a new variable called `answer_43`.
# >
# >> *Hint 1*: the `&` operator works elementwise on boolean series (like `and` in core python).
# >
# >> *Hint 2*: copying of the dataframe is done with the `copy` method for DataFrames.

# %%
# [Answer to Ex. 4.1.3 here]


# YOUR CODE HERE
answer_43 = answer_42[(answer_42.station == 'ITE00100550') & (answer_42.obs_type == 'TMAX')].copy()

# How copying does work: .copy() creates a copy of the dataframe and stores it in a new variable.

# %%
assert 'ITE00100550' in [answer_43[i].min() for i in answer_43]
assert 'ITE00100550' in [answer_43[i].max() for i in answer_43]
assert 'TMAX' in [answer_43[i].min() for i in answer_43]
assert 'TMAX' in [answer_43[i].max() for i in answer_43]

# %% [markdown]
# > **Ex. 4.1.4:** Make a new column in `answer_44` called `TMAX_F` where you have converted the temperature variables to Fahrenheit. Make sure not to overwrite `answer_43`.
# >
# > Store the resulting dataframe in a variable called `answer_44`.
# >
# >> *Hint*: Conversion is $F = 32 + 1.8*C$ where $F$ is Fahrenheit and $C$ is Celsius.

# %%
# [Answer to Ex. 4.1.4 here]
answer_44 = answer_43.copy()

# YOUR CODE HERE
answer_44['TMAX_F'] = 32 + 1.8 * answer_44['obs_value']

# %%
assert set(answer_44.columns) -  set(answer_43.columns) == {'TMAX_F'}

# %% [markdown]
# ## Problems from exercise set 5

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns 

# %matplotlib inline 

iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')

# %% [markdown]
# > **Ex. 5.1.1:**: Show the first five rows of the titanic dataset. What information is in the dataset? Use a barplot to show the probability of survival for men and women within each passenger class. Can you make a boxplot showing the same information (why/why not?). _Bonus:_ show a boxplot for the fare-prices within each passenger class.
# >
# > Spend five minutes discussing what you can learn about the survival-selection aboard titanic from the figure(s).
# >
# > > _Hint:_ https://seaborn.pydata.org/generated/seaborn.barplot.html, specifically the `hue` option.

# %%
# [Answer to Ex. 5.1.1 here]

# YOUR CODE HERE
titanic.head(5)

# the dataset contains information about the passengers on the Titanic,
# e.g. sex, passenger class, whether they survived or not, etc.

bar = sns.barplot(x='pclass', y='survived', hue='sex', data=titanic)

# the barplot clearly shows that the survival rate is higher for women than
# for men regardless of passenger class, and female survival rate is
# highest within passengerclass 1 and 2.

# %%
# boxplot of prop of survival
box = sns.boxplot(x='pclass', y='survived', hue='sex', data=titanic)

# the boxplot is very informative when it comes to describing probability
# of survival, since the min and max of survival will always be 0 and 1, 
# respectively, and the median will be 0.5.

# %%
# bonus boxplot
bonus = sns.boxplot(x='pclass', y='fare', data=titanic)

# %% [markdown]
# > **Ex. 5.1.2:** Using the iris flower dataset, draw a scatterplot of sepal length and petal length. Include a second order polynomial fitted to the data. Add a title to the plot and rename the axis labels.
# > _Discuss:_ Is this a meaningful way to display the data? What could we do differently?
# >
# > For a better understanding of the dataset this image might be useful:
# > <img src="iris_pic.png" alt="Drawing" style="width: 200px;"/>
# >
# >> _Hint:_ use the `.regplot` method from seaborn.

# %%
# [Answer to Ex. 5.1.2 here]

# YOUR CODE HERE
scatter = sns.regplot(x=iris['petal_length'], y=iris['sepal_length'], order=2).set_title('Sepal and petal length')
plt.xlabel('Petal length')
plt.ylabel('Sepal length')

#Discussion: It is not meaningful to display the data as a scatterplot. If Sepal and Petal 
#are correlations between the width and the length between two different leaves. One could 
#make a descriptive plot, where one shows the difference in the correlation between the 
#two different leaves.
# Out:
# Text(0, 0.5, 'Sepal length')

# %% [markdown]
# > **Ex. 5.1.3:** Combine the two of the figures you created above into a two-panel figure similar to the one shown here:
# > <img src="Example.png" alt="Drawing" style="width: 600px;"/>
# >
# > Save the figure as a png file on your computer.
# >> _Hint:_ See [this question](https://stackoverflow.com/questions/41384040/subplot-for-seaborn-boxplot) on stackoverflow for inspiration.

# %%
# [Answer to Ex. 5.1.3 here]

# YOUR CODE HERE
#raise NotImplementedError()
fig, axes =plt.subplots(1,2, figsize=(10,5))

#sns.regplot(x=iris['sepal_length'],y=iris['petal_length'], order=2, ax=axes[0]).set_title('Iris')
sns.regplot(x=iris['petal_length'],y=iris['sepal_length'], order=2, ax=axes[0]).set_title('Iris')
sns.barplot(x='pclass', y='survived', hue='sex', data=titanic, ax=axes[1]).set_title('Titianic')
plt.tight_layout()
axes[1].set_ylim([0,1])
fig.savefig('plotE.png')

# %% [markdown]
# > **Ex. 5.1.4:** Use [pairplot with hue](https://seaborn.pydata.org/generated/seaborn.pairplot.html) to create a figure that clearly shows how the different species vary across measurements. Change the color palette and remove the shading from the density plots. _Bonus:_ Try to explain how the `diag_kws` argument works (_hint:_ [read here](https://stackoverflow.com/questions/1769403/understanding-kwargs-in-python))

# %%
# [Answer to Ex. 5.1.4 here]

# YOUR CODE HERE
plt.style.use('default')
sns.set_palette("pastel")
f=sns.pairplot(iris, height=2.3, hue='species', diag_kws=dict(shade=False))

# The diag_kws argument enables us to call functions by constructing
# a dictionary of keyword arguments and add them to our function.

# %% [markdown]
# ## Problems from exercise set 6
#
# > _Note:_ In the exercises we asked you to download weather data from the NOAA website. For this assignment the data are loaded in the following code cell into two pandas dataframes.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

weather_1864 = pd.read_csv('weather_data_1864.csv')

# %% [markdown]
# > **Ex. 6.1.4:** Extract the country code from the station name into a separate column.
# >
# > Create a new column in `weather_1864` called `answer_61` and store the country codes here.
# >
# >> _Hint:_ The station column contains a GHCND ID, given to each weather station by NOAA. The format of these ID's is a 2-3 letter country code, followed by a integer identifying the specific station. A simple approach is to assume a fixed length of the country ID. A more complex way would be to use the [`re`](https://docs.python.org/2/library/re.html) module.

# %%
# [Answer to Ex. 6.1.4]
# weather_1864['answer_61'] =

# YOUR CODE HERE
weather_1864['answer_61'] = weather_1864['station']
weather_1864['answer_61'] = weather_1864['answer_61'].str[0:2]

weather_1864.head()
# Out:
#        station  datetime obs_type  obs_value  TMAX_F datetime_dt answer_61
# 0  SZ000006717  18640226     TMAX      -34.0  -29.20  1864-02-26        SZ
# 1  SZ000006717  18640208     TMAX      -17.4    0.68  1864-02-08        SZ
# 2  CA006158350  18640217     TMAX      -16.7    1.94  1864-02-17        CA
# 3  SZ000006717  18640103     TMAX      -16.5    2.30  1864-01-03        SZ
# 4  CA006158350  18640102     TMAX      -16.1    3.02  1864-01-02        CA

# %%
assert sorted(weather_1864['answer_61'].str[:2].unique()) == sorted(['SZ', 'CA', 'EZ', 'GM', 'AU', 'IT', 'BE', 'UK', 'EI', 'AG', 'AS'])

# %% [markdown]
# > **Ex. 6.1.5:** Make a function that downloads and formats the weather data according to previous exercises in Exercise Section 4.1, 6.1. You should use data for ALL stations but still only select maximal temperature. _Bonus:_ To validate that your function works plot the temperature curve for each country in the same window. Use `plt.legend()` to add a legend.
# >
# > Name your function `prepareWeatherData`.

# %%
# [Answer to Ex. 6.1.5]

def prepareWeatherData(year):
    url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/{y}.csv.gz'.format(y=str(year))

    df_weather = pd.read_csv(url, header=None).iloc[:,:4]
    
    df_weather.columns = ['station', 'datetime', 'obs_type', 'obs_value']
    df_weather['obs_value'] = df_weather['obs_value'] / 10  
    df_select = df_weather[(df_weather.obs_type == 'TMAX')].copy()
    df_select['TMAX_F'] = 32 + 1.8 * df_select['obs_value']
    df_sorted = df_select.reset_index(drop=True).sort_values(by=['obs_value'])
    df_sorted['year'] = year
    
    return df_sorted

# %%
assert prepareWeatherData('1864').shape == (5686, 6)

# %%
prepareWeatherData('1864')
# Out:
#           station  datetime obs_type  obs_value  TMAX_F  year
# 845   SZ000006717  18640226     TMAX      -34.0  -29.20  1864
# 577   SZ000006717  18640208     TMAX      -17.4    0.68  1864
# 699   CA006158350  18640217     TMAX      -16.7    1.94  1864
# 42    SZ000006717  18640103     TMAX      -16.5    2.30  1864
# 16    CA006158350  18640102     TMAX      -16.1    3.02  1864
# 607   SZ000006717  18640210     TMAX      -15.9    3.38  1864
# 199   EZE00100082  18640114     TMAX      -15.1    4.82  1864
# 592   SZ000006717  18640209     TMAX      -15.0    5.00  1864
# 741   SZ000006717  18640219     TMAX      -14.7    5.54  1864
# 533   SZ000006717  18640205     TMAX      -14.4    6.08  1864
# 756   SZ000006717  18640220     TMAX      -14.2    6.44  1864
# 229   EZE00100082  18640116     TMAX      -14.2    6.44  1864
# 714   CA006158350  18640218     TMAX      -13.9    6.98  1864
# 562   SZ000006717  18640207     TMAX      -13.8    7.16  1864
# 184   EZE00100082  18640113     TMAX      -13.8    7.16  1864
# 726   SZ000006717  18640218     TMAX      -13.3    8.06  1864
# 69    GM000004204  18640105     TMAX      -12.5    9.50  1864
# 243   EZE00100082  18640117     TMAX      -12.2   10.04  1864
# 273   EZE00100082  18640119     TMAX      -12.2   10.04  1864
# 54    GM000004204  18640104     TMAX      -12.1   10.22  1864
# 5559  SZ000006717  18641223     TMAX      -11.8   10.76  1864
# 5531  CA006158350  18641222     TMAX      -11.7   10.94  1864
# 265   SZ000006717  18640118     TMAX      -11.6   11.12  1864
# 622   SZ000006717  18640211     TMAX      -11.6   11.12  1864
# 49    GME00125218  18640104     TMAX      -11.5   11.30  1864
# 1334  SZ000006717  18640330     TMAX      -11.3   11.66  1864
# 5597  EZE00100082  18641226     TMAX      -11.2   11.84  1864
# 72    SZ000006717  18640105     TMAX      -11.1   12.02  1864
# 5567  EZE00100082  18641224     TMAX      -11.0   12.20  1864
# 28    SZ000006717  18640102     TMAX      -10.7   12.74  1864
# ...           ...       ...      ...        ...     ...   ...
# 3568  AGE00135039  18640819     TMAX       33.0   91.40  1864
# 3240  ITE00100554  18640729     TMAX       33.0   91.40  1864
# 3358  ITE00100550  18640806     TMAX       33.1   91.58  1864
# 3287  ITE00100554  18640801     TMAX       33.1   91.58  1864
# 1084  ASN00086071  18640314     TMAX       33.3   91.94  1864
# 5183  ASN00086071  18641130     TMAX       33.3   91.94  1864
# 3407  CA006158350  18640809     TMAX       33.3   91.94  1864
# 5309  ASN00086071  18641208     TMAX       33.3   91.94  1864
# 3413  ITE00100554  18640809     TMAX       33.4   92.12  1864
# 3279  ITE00100550  18640801     TMAX       33.5   92.30  1864
# 3342  ITE00100550  18640805     TMAX       33.5   92.30  1864
# 3381  ITE00100554  18640807     TMAX       33.6   92.48  1864
# 290   ASN00066062  18640120     TMAX       33.9   93.02  1864
# 2696  CA006158350  18640625     TMAX       33.9   93.02  1864
# 30    ASN00086071  18640103     TMAX       33.9   93.02  1864
# 5545  ASN00086071  18641223     TMAX       33.9   93.02  1864
# 3423  CA006158350  18640810     TMAX       33.9   93.02  1864
# 3397  ITE00100554  18640808     TMAX       33.9   93.02  1864
# 3189  AGE00135039  18640726     TMAX       34.0   93.20  1864
# 3389  ITE00100550  18640808     TMAX       34.1   93.38  1864
# 379   ASN00066062  18640126     TMAX       34.3   93.74  1864
# 52    ASN00066062  18640104     TMAX       34.3   93.74  1864
# 3391  CA006158350  18640808     TMAX       34.4   93.92  1864
# 713   ASN00086071  18640218     TMAX       34.5   94.10  1864
# 3294  ITE00100550  18640802     TMAX       34.6   94.28  1864
# 3366  ITE00100554  18640806     TMAX       34.7   94.46  1864
# 3405  ITE00100550  18640809     TMAX       34.8   94.64  1864
# 3350  ITE00100554  18640805     TMAX       35.5   95.90  1864
# 3302  ITE00100554  18640802     TMAX       35.6   96.08  1864
# 104   ASN00086071  18640108     TMAX       35.9   96.62  1864
#
# [5686 rows x 6 columns]

# %% [markdown]
# ## Problems from exercise set 7
#
# > _Note:_ Once again if you haven't managed to download the data from NOAA, you can refer to the github repo to get csv-files containing the required data.

# %%
# %matplotlib inline 

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl

# Increases the plot size a little
mpl.rcParams['figure.figsize'] = 11, 6

# %%
def weatherdata(yr):
    url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/'+str(yr)+'.csv.gz'
    df = pd.read_csv(url, sep=',',compression="gzip",header=None)
    df1 = df.drop(columns=[4,5,6,7])
    df1.columns = ['station','date','type','temp']
    df1_max = df1.loc[(df1['type']=='TMAX')]
    df1_max['TMAX_F'] = df1_max['temp']*1.8+32
    df1_max.reset_index(inplace=True, drop=True)
    df1_max.sort_values(by='temp', inplace=True)
    df1_max['date'] = pd.to_datetime(df1_max['date'], format='%Y%m%d')
    df1_max['month'] = df1_max['date'].dt.month
    df1_max.set_index(df1_max['date'], inplace=True)
    df1_max['countrycode'] = df1_max['station'].str.extract('([A-Z]+)')
    return df1_max

weatherdata(1864).head()
# Out:
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                 station       date  type  temp  TMAX_F  month countrycode
# date
# 1864-02-26  SZ000006717 1864-02-26  TMAX  -340  -580.0      2          SZ
# 1864-02-08  SZ000006717 1864-02-08  TMAX  -174  -281.2      2          SZ
# 1864-02-17  CA006158350 1864-02-17  TMAX  -167  -268.6      2          CA
# 1864-01-03  SZ000006717 1864-01-03  TMAX  -165  -265.0      1          SZ
# 1864-01-02  CA006158350 1864-01-02  TMAX  -161  -257.8      1          CA

# %% [markdown]
# > **Ex. 7.1.1:** Plot the monthly max,min, mean, first and third quartiles for maximum temperature for our station with the ID _'ITE00100550'_ in 1864.
#
# > *Hint*: the method `describe` computes all these measures.

# %%
# [Answer to Ex. 7.1.1]

# YOUR CODE HERE
data = weatherdata(1864)

data.head()

ite =  data.loc[(data['station']=='ITE00100550') & (data['type']=='TMAX')].copy()
ite.groupby("month")["temp"].describe().plot(y=["25%", "75%", "min", "mean", "max"])
# Out:
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %% [markdown]
# > **Ex. 7.1.2:** Get the processed data from years 1864-1867 as a list of DataFrames. Convert the list into a single DataFrame by concatenating vertically.
# >
# > Name the concatenated data `answer_72`

# %%
# [Answer to Ex. 7.1.2]

# YOUR CODE HERE
data1 = weatherdata(1865)
data2 = weatherdata(1866)
data3 = weatherdata(1867)

# vertical concetenation
answer_72=pd.concat([data,data1,data2,data3], join='outer', axis=0)
answer_72.head(4)
# Out:
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                 station       date  type  temp  TMAX_F  month countrycode
# date
# 1864-02-26  SZ000006717 1864-02-26  TMAX  -340  -580.0      2          SZ
# 1864-02-08  SZ000006717 1864-02-08  TMAX  -174  -281.2      2          SZ
# 1864-02-17  CA006158350 1864-02-17  TMAX  -167  -268.6      2          CA
# 1864-01-03  SZ000006717 1864-01-03  TMAX  -165  -265.0      1          SZ

# %%
answer_72.shape
# Out:
# (30003, 7)

# %%
assert answer_72.shape == (30003, 7)

# %% [markdown]
# > **Ex. 7.1.3:** Parse the station location data which you can find at https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt. Merge station locations onto the weather data spanning 1864-1867.
# >
# > Store the merged data in a new variable called `answer_73`.
# >
# > _Hint:_ The location data have the folllowing format,
#
# ```
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------
# ```
#
# > *Hint*: The station information has fixed width format - does there exist a pandas reader for that?

# %%
# [Answer to Ex. 7.1.3]

# YOUR CODE HERE
url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt'

# fixed width format
df_location = pd.read_fwf(url)

df_location.columns=['station','latitude','longitude','elevation','name','gsn_flag','hcn_crn_flag','wmo_id']
df_location["random"] = df_location["elevation"]

print(df_location.head())
# Out:
#        station  latitude  longitude  elevation                 name gsn_flag  \
# 0  ACW00011647   17.1333   -61.7833       19.2             ST JOHNS      NaN
# 1  AE000041196   25.3330    55.5170       34.0  SHARJAH INTER. AIRP      NaN
# 2  AEM00041194   25.2550    55.3640       10.4           DUBAI INTL      NaN
# 3  AEM00041217   24.4330    54.6510       26.8       ABU DHABI INTL      NaN
# 4  AEM00041218   24.2620    55.6090      264.9          AL AIN INTL      NaN
#
#   hcn_crn_flag   wmo_id  random
# 0          NaN      NaN    19.2
# 1          GSN  41196.0    34.0
# 2          NaN  41194.0    10.4
# 3          NaN  41217.0    26.8
# 4          NaN  41218.0   264.9

# %%
answer_73 = pd.merge(answer_72,df_location, how='inner')
answer_73.head(4)
# Out:
#        station       date  type  temp  TMAX_F  month countrycode  latitude  \
# 0  SZ000006717 1864-02-26  TMAX  -340  -580.0      2          SZ   45.8667
# 1  SZ000006717 1864-02-08  TMAX  -174  -281.2      2          SZ   45.8667
# 2  SZ000006717 1864-01-03  TMAX  -165  -265.0      1          SZ   45.8667
# 3  SZ000006717 1864-02-10  TMAX  -159  -254.2      2          SZ   45.8667
#
#    longitude  elevation                     name gsn_flag hcn_crn_flag  \
# 0     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
# 1     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
# 2     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
# 3     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
#
#    wmo_id  random
# 0  6717.0  2472.0
# 1  6717.0  2472.0
# 2  6717.0  2472.0
# 3  6717.0  2472.0

# %%
answer_73.shape
# Out:
# (30003, 15)

# %%
assert answer_73.shape == (5686, 15) or answer_73.shape == (30003, 15)

# %% [markdown]
# ## Problems from exercise set 8
#
# > **Ex. 8.1.2.:** Use the `request` module to collect the first page of job postings.
# >
# > Store the response.json() object in a new variable called `answer_81`.
# >

# %%
# [Answer to Ex. 8.1.2]

# YOUR CODE HERE
import pandas as pd
import requests
url = 'https://job.jobnet.dk/CV/FindWork/Search'

r = requests.get(url)
r.status_code
answer_81 = r.json()
answer_81
# Out:
# {'Expression': {'ShowNearbyCriteria': True,
#   'Offset': 0,
#   'Count': 20,
#   'SearchString': None,
#   'SortValue': None,
#   'Id': [],
#   'EarliestPublicationDate': '0001-01-01T00:00:00',
#   'HotJob': False,
#   'Abroad': False,
#   'NearBy': None,
#   'ExternalJob': None,
#   'WorkPlaceNotStatic': None,
#   'OnlyGeoPoints': False,
#   'Facets': {'Region': [],
#    'Country': [],
#    'Municipality': [],
#    'PostalCode': [],
#    'OccupationAreas': [],
#    'OccupationGroups': [],
#    'Occupations': [],
#    'EmploymentType': [],
#    'WorkHours': [],
#    'JobAnnouncementType': [],
#    'WorkPlaceNotStatic': []},
#   'LocatedIn': None,
#   'LocationZip': None,
#   'Location': None,
#   'SearchInGeoDistance': 0},
#  'Facets': {'Region': [{'Id': 0,
#     'Value': 'Hovedstaden og Bornholm',
#     'Count': 5496},
#    {'Id': 0, 'Value': 'Midtjylland', 'Count': 3253},
#    {'Id': 0, 'Value': 'Syddanmark', 'Count': 2615},
#    {'Id': 0, 'Value': 'Øvrige Sjælland', 'Count': 1546},
#    {'Id': 0, 'Value': 'Nordjylland', 'Count': 1208},
#    {'Id': 0, 'Value': 'fagforeningsarbejde', 'Count': 9},
#    {'Id': 0, 'Value': 'postarbejde', 'Count': 9},
#    {'Id': 0,
#     'Value': 'tværgående arbejde, pædagogisk og socialt arbejde',
#     'Count': 9},
#    {'Id': 0, 'Value': 'medicoarbejde', 'Count': 8},
#    {'Id': 0, 'Value': 'dyrepleje og opdræt', 'Count': 7},
#    {'Id': 0,
#     'Value': 'tværgående arbejde, nærings- og nydelsesmiddel',
#     'Count': 7},
#    {'Id': 0, 'Value': 'jordbrug, miljø og grøn forvaltning', 'Count': 7},
#    {'Id': 0, 'Value': 'design, formgivning og grafisk arbejde', 'Count': 6},
#    {'Id': 0, 'Value': 'bibiliotekar- og arkivararbejde', 'Count': 6},
#    {'Id': 0, 'Value': 'skrædder-, sy- og tilskærerarbejde ', 'Count': 6},
#    {'Id': 0, 'Value': 'have- og parkarbejde', 'Count': 6},
#    {'Id': 0, 'Value': 'redaktionsarbejde', 'Count': 6},
#    {'Id': 0, 'Value': 'autolakeringsarbejde', 'Count': 6},
#    {'Id': 0, 'Value': 'biblioteks- og museumsarbejde', 'Count': 6},
#    {'Id': 0, 'Value': 'tværgående arbejde, tekstil og beklædning', 'Count': 6},
#    {'Id': 0, 'Value': 'transport, lager og logistik', 'Count': 6},
#    {'Id': 0, 'Value': 'optræden, forlystelses- og modelarbejde', 'Count': 5},
#    {'Id': 0,
#     'Value': 'øvrigt arbejde inden for tekstil og beklædning mv.',
#     'Count': 5},
#    {'Id': 0, 'Value': 'træ, møbel, glas og keramik', 'Count': 5},
#    {'Id': 0, 'Value': 'terapeutisk arbejde', 'Count': 5},
#    {'Id': 0, 'Value': 'gartneri, produktion', 'Count': 5},
#    {'Id': 0,
# ...
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-08-25T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031553',
#    'Region': 'Hovedstaden og Bornholm',
#    'Municipality': 'Vallensbæk',
#    'Country': 'Danmark',
#    'PostalCode': '2665',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Deltid',
#    'OccupationArea': 'Hotel, restauration, køkken, kantine ',
#    'OccupationGroup': 'køkken- og kantinearbejde',
#    'Occupation': 'kok',
#    'Location': {'Latitude': 55.6241, 'Longitude': 12.3867},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 7542,
#    'OrganisationId': '8775',
#    'HiringOrgCVR': 19583910,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031553',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031553',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031553',
#    'HasLocationValues': True,
#    'ID': '5031553',
#    'Latitude': 55.6241,
#    'Longitude': 12.3867},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'stilladsmontører søges',
#    'JobHeadline': 'stilladsmontører søges',
#    'Presentation': '<p>Job&oslash;st s&oslash;ger for kunde til fastans&aelig;ttelse i Hvidovre-firma:</p>\n<p>Stilladsmont&oslash;rer med Systemstillads. Gerne erfaring men ikke et krav.</p>\n<p>Dansktalende, stabil, god ',
#    'HiringOrgName': 'Just Jobs',
#    'WorkPlaceAddress': '',
#    'WorkPlacePostalCode': '',
#    'WorkPlaceCity': '',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': True,
#    'UseWorkPlaceAddressForJoblog': False,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-08-31T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031549',
#    'Region': '',
#    'Municipality': '',
#    'Country': 'Danmark',
#    'PostalCode': '4320',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Bygge og anlæg',
#    'OccupationGroup': 'bygningsarbejde mv.',
#    'Occupation': 'stilladsmontør',
#    'Location': {'Latitude': 55.5946, 'Longitude': 11.957},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 116038,
#    'OrganisationId': '103427',
#    'HiringOrgCVR': 18158345,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031549',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031549',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031549',
#    'HasLocationValues': True,
#    'ID': '5031549',
#    'Latitude': 55.5946,
#    'Longitude': 11.957},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Afdelingsleder i Vestbjerg',
#    'JobHeadline': 'Afdelingsleder i Vestbjerg',
#    'Presentation': '<strong>Afdelingsleder til Vestbjerg Skole</strong><br><br>Vestbjerg Skole er placeret "på toppen" af Vestbjerg grænsende op til Hammer Bakker og er en del af Aalborg kommunale skolevæsen. Skolen ',
#    'HiringOrgName': 'Vestbjerg Skole',
#    'WorkPlaceAddress': 'Bakmøllevej 280',
#    'WorkPlacePostalCode': '9380',
#    'WorkPlaceCity': 'Vestbjerg',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-09-06T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031550',
#    'Region': 'Nordjylland',
#    'Municipality': 'Aalborg',
#    'Country': 'Danmark',
#    'PostalCode': '9380',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Ledelse',
#    'OccupationGroup': 'administration, strategi og personale',
#    'Occupation': 'afdelingschef',
#    'Location': {'Latitude': 57.1357, 'Longitude': 9.9617},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 96985,
#    'OrganisationId': '58491',
#    'HiringOrgCVR': 29189420,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031550',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031550',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031550',
#    'HasLocationValues': True,
#    'ID': '5031550',
#    'Latitude': 57.1357,
#    'Longitude': 9.9617},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Online markedsføringsmedarbejder til SaaS-virksomheden NemTilmeld.dk',
#    'JobHeadline': 'Online markedsføringsmedarbejder til SaaS-virksomheden NemTilmeld.dk',
#    'Presentation': '<p>Br&aelig;nder du for at lave online markedsf&oslash;ring, og har du en relevant teoretisk uddannelse indenfor&nbsp; for omr&aring;det?<br>S&aring; er det dig, vi mangler p&aring; vores hold.',
#    'HiringOrgName': 'NemTimeld.dk ApS',
#    'WorkPlaceAddress': 'Strømmen 6',
#    'WorkPlacePostalCode': '9400',
#    'WorkPlaceCity': 'Nørresundby',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-08-25T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031547',
#    'Region': 'Nordjylland',
#    'Municipality': 'Aalborg',
#    'Country': 'Danmark',
#    'PostalCode': '9400',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Salg, indkøb og markedsføring',
#    'OccupationGroup': 'marketing',
#    'Occupation': 'marketingmedarbejder',
#    'Location': {'Latitude': 57.0862, 'Longitude': 9.9581},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': 'Dag'},
#    'IsCvOwner': False,
#    'WorkplaceID': 49184,
#    'OrganisationId': '50496',
#    'HiringOrgCVR': 27673120,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031547',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031547',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031547',
#    'HasLocationValues': True,
#    'ID': '5031547',
#    'Latitude': 57.0862,
#    'Longitude': 9.9581},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Ledende oversygeplejerske søges til Mave-Tarm Kirurgisk Afdeling på Slagelse Sygehus',
#    'JobHeadline': 'Ledende oversygeplejerske søges til Mave-Tarm Kirurgisk Afdeling på Slagelse Sygehus',
#    'Presentation': '\n\t\n\t\t\n\t\t\t\n\t\t\n\t\n\n\n<p>Til vores ambiti&oslash;se Mave-Tarm Kirurgiske Afdeling s&oslash;ger vi en ny sygeplejefaglig st&aelig;rk og engageret ledende oversygeplejerske. Vi l&aelig;gger v&aelig;gt p&arin',
#    'HiringOrgName': 'Region Sjælland',
#    'WorkPlaceAddress': 'Fælledvej 11',
#    'WorkPlacePostalCode': '4200',
#    'WorkPlaceCity': 'Slagelse',
#    'WorkPlaceOtherAddress': True,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': False,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-09-03T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031548',
#    'Region': 'Øvrige Sjælland',
#    'Municipality': 'Slagelse',
#    'Country': 'Danmark',
#    'PostalCode': '4200',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Ledelse',
#    'OccupationGroup': 'administration, strategi og personale',
#    'Occupation': 'afdelingschef',
#    'Location': {'Latitude': 55.4008, 'Longitude': 11.3688},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 61350,
#    'OrganisationId': '57914',
#    'HiringOrgCVR': 29190658,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031548',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031548',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031548',
#    'HasLocationValues': True,
#    'ID': '5031548',
#    'Latitude': 55.4008,
#    'Longitude': 11.3688},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Sælger søges til Glitter i Rosengårdscenteret, Odense',
#    'JobHeadline': 'Sælger søges til Glitter i Rosengårdscenteret, Odense',
#    'Presentation': '<p>',
#    'HiringOrgName': 'Glitter Rosengårds Centeret',
#    'WorkPlaceAddress': 'Ørbækvej 75',
#    'WorkPlacePostalCode': '5220',
#    'WorkPlaceCity': 'Odense SØ',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-10-11T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031545',
#    'Region': 'Syddanmark',
#    'Municipality': 'Odense',
#    'Country': 'Danmark',
#    'PostalCode': '5220',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Deltid',
#    'OccupationArea': 'Salg, indkøb og markedsføring',
#    'OccupationGroup': 'butiksekspedition',
#    'Occupation': 'butiksassistent',
#    'Location': {'Latitude': 55.3825, 'Longitude': 10.4281},
#    'JoblogWorkTime': {'WorkHour': '(20 timer ugentligt)',
#     'DailyWorkTime': 'Dag, aften, weekend'},
#    'IsCvOwner': False,
#    'WorkplaceID': 132599,
#    'OrganisationId': '116295',
#    'HiringOrgCVR': 26378427,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031545',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031545',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031545',
#    'HasLocationValues': True,
#    'ID': '5031545',
#    'Latitude': 55.3825,
#    'Longitude': 10.4281},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Receptionist / administrativ medarbejder',
#    'JobHeadline': 'Receptionist / administrativ medarbejder',
#    'Presentation': '<strong>Bliv en del af Memox!</strong> <br><br>  <br><br> Vi søger en receptionist, der kan varetage administrative opgaver. <br><br>  <br><br> Bliv en del af Memox, hvor vi hver dag arbejder for at s',
#    'HiringOrgName': 'Memox og Øresund Psykoterapi ApS',
#    'WorkPlaceAddress': 'Eliasgade 10',
#    'WorkPlacePostalCode': '2300',
#    'WorkPlaceCity': 'København S',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-08-30T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031546',
#    'Region': 'Hovedstaden og Bornholm',
#    'Municipality': 'København',
#    'Country': 'Danmark',
#    'PostalCode': '2300',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Kontor, administration, regnskab og finans',
#    'OccupationGroup': 'receptions- og kontorarbejde, øvrigt',
#    'Occupation': 'receptionist, kontor',
#    'Location': {'Latitude': 55.6659, 'Longitude': 12.6184},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 123290,
#    'OrganisationId': '109035',
#    'HiringOrgCVR': 37851582,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031546',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031546',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031546',
#    'HasLocationValues': True,
#    'ID': '5031546',
#    'Latitude': 55.6659,
#    'Longitude': 12.6184},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Mac Baren søger en engageret og detaljeorienteret produktionsplanlægger/indkøbsdisponent',
#    'JobHeadline': 'Mac Baren søger en engageret og detaljeorienteret produktionsplanlægger/indkøbsdisponent',
#    'Presentation': '<p>\n\n<p> </p>\n\n<em>Kunne du tænke dig at arbejde i en international virksomhed, der efter 132 år stadig er i vækst, og hvor frihed under ansvar er en grundsten i vores gode arbejdsmiljø?</em>\n\n<p>',
#    'HiringOrgName': 'Halberg A/S',
#    'WorkPlaceAddress': 'Porthusvej 100',
#    'WorkPlacePostalCode': '5700',
#    'WorkPlaceCity': 'Svendborg',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-09-08T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031538',
#    'Region': 'Syddanmark',
#    'Municipality': 'Svendborg',
#    'Country': 'Danmark',
#    'PostalCode': '5700',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Salg, indkøb og markedsføring',
#    'OccupationGroup': 'salg og indkøb',
#    'Occupation': 'logistikmedarbejder, salg og indkøb',
#    'Location': {'Latitude': 55.0744, 'Longitude': 10.61},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 0,
#    'OrganisationId': '0',
#    'HiringOrgCVR': 34076510,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031538',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031538',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031538',
#    'HasLocationValues': True,
#    'ID': '5031538',
#    'Latitude': 55.0744,
#    'Longitude': 10.61},
#   {'AutomatchType': 0,
#    'Weight': 1.0,
#    'Title': 'Afdelingsskoleleder til udskolingen på Borgerskoleafdelingen',
#    'JobHeadline': 'Afdelingsskoleleder til udskolingen på Borgerskoleafdelingen',
#    'Presentation': '',
#    'HiringOrgName': 'Borgerskoleafdelingen',
#    'WorkPlaceAddress': 'Skimminge 19A',
#    'WorkPlacePostalCode': '4930',
#    'WorkPlaceCity': 'Maribo',
#    'WorkPlaceOtherAddress': False,
#    'WorkPlaceAbroad': False,
#    'WorkPlaceNotStatic': False,
#    'UseWorkPlaceAddressForJoblog': True,
#    'PostingCreated': '2019-08-16T00:00:00',
#    'LastDateApplication': '2019-09-15T00:00:00',
#    'AssignmentStartDate': '0001-01-01T00:00:00',
#    'IsHotjob': False,
#    'IsExternal': False,
#    'Url': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031544',
#    'Region': 'Øvrige Sjælland',
#    'Municipality': 'Lolland',
#    'Country': 'Danmark',
#    'PostalCode': '4930',
#    'PostalCodeName': None,
#    'JobAnnouncementType': '',
#    'EmploymentType': '',
#    'WorkHours': 'Fuldtid',
#    'OccupationArea': 'Ledelse',
#    'OccupationGroup': 'undervisning og forskning',
#    'Occupation': 'skoleleder',
#    'Location': {'Latitude': 54.7734, 'Longitude': 11.5084},
#    'JoblogWorkTime': {'WorkHour': None, 'DailyWorkTime': None},
#    'IsCvOwner': False,
#    'WorkplaceID': 127167,
#    'OrganisationId': '58275',
#    'HiringOrgCVR': 29188572,
#    'AnonymousEmployer': False,
#    'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5031544',
#    'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5031544',
#    'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/JobDetail/5031544',
#    'HasLocationValues': True,
#    'ID': '5031544',
#    'Latitude': 54.7734,
#    'Longitude': 11.5084}],
#  'TotalResultCount': 14769}

# %%
assert sorted(answer_81.keys()) == sorted(['Expression', 'Facets', 'JobPositionPostings', 'TotalResultCount'])

# %% [markdown]
# > **Ex. 8.1.3.:** Store the 'TotalResultCount' value for later use. Also create a dataframe from the 'JobPositionPostings' field in the json. Name this dataframe `answer_82`.

# %%
# [Answer to Ex. 8.1.3]
# answer_82 = 

TotalResultCount = 14769

# YOUR CODE HERE
answer_82 = pd.DataFrame((answer_81['JobPositionPostings']))
answer_82.head(20)
# Out:
#     AnonymousEmployer  AssignmentStartDate  AutomatchType  Country  \
# 0               False  0001-01-01T00:00:00              0  Danmark
# 1               False  0001-01-01T00:00:00              0  Danmark
# 2               False  0001-01-01T00:00:00              0  Danmark
# 3               False  0001-01-01T00:00:00              0  Danmark
# 4               False  0001-01-01T00:00:00              0  Danmark
# 5               False  0001-01-01T00:00:00              0  Danmark
# 6               False  0001-01-01T00:00:00              0  Danmark
# 7               False  0001-01-01T00:00:00              0  Danmark
# 8               False  0001-01-01T00:00:00              0  Danmark
# 9               False  0001-01-01T00:00:00              0  Danmark
# 10              False  0001-01-01T00:00:00              0  Danmark
# 11              False  0001-01-01T00:00:00              0  Danmark
# 12              False  0001-01-01T00:00:00              0  Danmark
# 13              False  0001-01-01T00:00:00              0  Danmark
# 14              False  0001-01-01T00:00:00              0  Danmark
# 15              False  0001-01-01T00:00:00              0  Danmark
# 16              False  0001-01-01T00:00:00              0  Danmark
# 17              False  0001-01-01T00:00:00              0  Danmark
# 18              False  0001-01-01T00:00:00              0  Danmark
# 19              False  0001-01-01T00:00:00              0  Danmark
#
#                                            DetailsUrl EmploymentType  \
# 0   https://job.jobnet.dk/CV/FindWork/Details/5031564
# 1   https://job.jobnet.dk/CV/FindWork/Details/5031563
# 2   https://job.jobnet.dk/CV/FindWork/Details/5031562
# 3   https://job.jobnet.dk/CV/FindWork/Details/5031559
# 4   https://job.jobnet.dk/CV/FindWork/Details/5031558
# 5   https://job.jobnet.dk/CV/FindWork/Details/5031484
# 6   https://job.jobnet.dk/CV/FindWork/Details/5031557
# 7   https://job.jobnet.dk/CV/FindWork/Details/5031556
# 8   https://job.jobnet.dk/CV/FindWork/Details/5031555
# 9   https://job.jobnet.dk/CV/FindWork/Details/5031554
# 10  https://job.jobnet.dk/CV/FindWork/Details/5031553
# 11  https://job.jobnet.dk/CV/FindWork/Details/5031549
# 12  https://job.jobnet.dk/CV/FindWork/Details/5031550
# 13  https://job.jobnet.dk/CV/FindWork/Details/5031547
# 14  https://job.jobnet.dk/CV/FindWork/Details/5031548
# 15  https://job.jobnet.dk/CV/FindWork/Details/5031545
# 16  https://job.jobnet.dk/CV/FindWork/Details/5031546
# 17  https://job.jobnet.dk/CV/FindWork/Details/5031538
# 18  https://job.jobnet.dk/CV/FindWork/Details/5031544
# 19  https://job.jobnet.dk/CV/FindWork/Details/5031520
#
#     HasLocationValues  HiringOrgCVR                         HiringOrgName  \
# 0                True      99999999  Forsvarsministeriets Ejendomstyrelse
# 1                True      29188572         Udskoling Stormarksafdelingen
# 2                True      29188572                Indskoling Østofteafd.
# 3                True      31079179                           Storm Group
# 4                True      10692997                KULTORVET'S URE & GULD
# 5                True      29054304     Appetito - din italienske købmand
# 6                True      35759344                         KMK Rengøring
# 7                True      29220824                 Bowl'n'Fun Sønderborg
# 8                True      35759344                         KMK Rengøring
# 9                True      36538376             TANDLÆGE ANDREA GROTH ApS
# 10               True      19583910                    Vallensbæk Kommune
# 11               True      18158345                             Just Jobs
# 12               True      29189420                       Vestbjerg Skole
# 13               True      27673120                      NemTimeld.dk ApS
# 14               True      29190658                       Region Sjælland
# 15               True      26378427           Glitter Rosengårds Centeret
# 16               True      37851582      Memox og Øresund Psykoterapi ApS
# 17               True      34076510                           Halberg A/S
# 18               True      29188572                 Borgerskoleafdelingen
# 19               True      35529586                   Habitus Holding ApS
#
#          ID  ...  UseWorkPlaceAddressForJoblog  Weight  WorkHours  \
# 0   5031564  ...                          True     1.0    Fuldtid
# 1   5031563  ...                          True     1.0    Fuldtid
# 2   5031562  ...                          True     1.0    Fuldtid
# 3   5031559  ...                          True     1.0     Deltid
# 4   5031558  ...                          True     1.0    Fuldtid
# 5   5031484  ...                          True     1.0     Deltid
# 6   5031557  ...                         False     1.0     Deltid
# 7   5031556  ...                          True     1.0    Fuldtid
# 8   5031555  ...                         False     1.0     Deltid
# 9   5031554  ...                          True     1.0    Fuldtid
# 10  5031553  ...                          True     1.0     Deltid
# 11  5031549  ...                         False     1.0    Fuldtid
# 12  5031550  ...                          True     1.0    Fuldtid
# 13  5031547  ...                          True     1.0    Fuldtid
# 14  5031548  ...                         False     1.0    Fuldtid
# 15  5031545  ...                          True     1.0     Deltid
# 16  5031546  ...                          True     1.0    Fuldtid
# 17  5031538  ...                          True     1.0    Fuldtid
# 18  5031544  ...                          True     1.0    Fuldtid
# 19  5031520  ...                         False     1.0    Fuldtid
#
#    WorkPlaceAbroad             WorkPlaceAddress      WorkPlaceCity  \
# 0            False                Arsenalvej 55           Hjørring
# 1            False              Fastings Allé 1            Nakskov
# 2            False              Østofte Gade 42         Nørreballe
# 3            False       Vesterbrogade 12, 1.tv        København V
# 4            False          Frederiksborggade 4        København K
# 5            False               Tinghusgade 24          Svendborg
# 6            False                                      Sønderborg
# 7            False          Stenager 17, 1. sal         Sønderborg
# 8            False                                         Kolding
# 9            False                Vestergade 44           Odense C
# 10           False  Vallensbæk Stationstorv 100  Vallensbæk Strand
# 11           False
# 12           False              Bakmøllevej 280          Vestbjerg
# 13           False                   Strømmen 6        Nørresundby
# 14           False                 Fælledvej 11           Slagelse
# 15           False                  Ørbækvej 75          Odense SØ
# 16           False                 Eliasgade 10        København S
# 17           False               Porthusvej 100          Svendborg
# 18           False                Skimminge 19A             Maribo
# 19           False           Jernstøbervænget 7               Køge
#
#    WorkPlaceNotStatic WorkPlaceOtherAddress  WorkPlacePostalCode WorkplaceID
# 0               False                 False                 9800           0
# 1               False                 False                 4900       98858
# 2               False                 False                 4951      127167
# 3               False                 False                 1620      108432
# 4               False                 False                 1360       63825
# 5               False                 False                 5700       86269
# 6               False                  True                 6400      111332
# 7               False                 False                 6400           0
# 8               False                  True                 6000      111332
# 9               False                 False                 5000      132600
# 10              False                 False                 2665        7542
# 11               True                 False                           116038
# 12              False                 False                 9380       96985
# 13              False                 False                 9400       49184
# 14              False                  True                 4200       61350
# 15              False                 False                 5220      132599
# 16              False                 False                 2300      123290
# 17              False                 False                 5700           0
# 18              False                 False                 4930      127167
# 19              False                  True                 4600      128528
#
# [20 rows x 44 columns]

# %%
assert answer_82.shape == (20,44)
