# %% [markdown]
# # Mandatory Assignment 1
#
# This is the first of two mandatory assignments which must be completed during the course. First some practical information:
#
# * When is the assignment due?: **23:59, Sunday, August 19, 2018.**
# * How do you grade the assignment?: You will **peergrade** each other as primary grading.
# * Can i work with my group?: **yes**
#
# The assigment consist of one to tree problems from each of the exercise sets you have solved so far (excluding Set 1). We've tried to select problems which are self contained, but it might be nessecary to solve some of the previous exercises in each set to fully answer the problems in this assignment.
#
# ## Problems from Exercise Set 2:
#
# > **Ex. 2.2**: Make two lists. The first should be numbered. The second should be unnumbered and contain at least one sublevel.

# %%
# [Answer to Ex. 2.2 here] (convert to markdown cell)

# %% [markdown]
# # Numbered List
#
# 1. Item1
# 2. Item2
# 3. Item3

# %% [markdown]
# # Unnumbered list
#
# - Item1
# - Item2
# -- Item2.1
# -- Item2.3
# - Item3

# %% [markdown]
# ## Problems from Exercise set 3:
#
# > **Ex. 3.1.3:** Let `l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']`. Create from `l1` the sentence `"Is r > g?"` using your knowledge about string formatting. Store this new string in a variable called `answer_31`. Make sure there is only one space in between worlds.
# >
# >> _Hint:_ You should be able to combine the above informations to solve this exercise.

# %%
# [Answer to Ex. 3.1.3 here]
l1 = ['r ', 'Is', '>', ' < ', 'g ', '?']

# YOUR CODE HERE
answer_31 = l1[1]+" "+l1[0].strip() +" "+l1[2].strip() +" "+l1[4].strip()+"?" 

answer_31
# Out:
# 'Is r > g?'

# %%
assert answer_31 == "Is r > g?"

# %% [markdown]
# > **Ex. 3.1.4**: Create an empty dictionary `words` using the `dict()`function. Then add each of the words in `['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']` as a key, with the value being a boolean indicator for whether the word begins with a vowel. The results should look like `{'bacon': False, 'asynchronous': True ...}`. Store the result in a new variable called `answer_32`.
# >
# >> _Hint:_ You might want co first construct a function that asseses whether a given word begins with a vowel or not.

# %%
# [Answer to Ex. 3.1.4 here]
W = ['animal', 'coffee', 'python', 'unit', 'knowledge', 'tread', 'arise']

# answer_32 = 



# YOUR CODE HERE

def vowel(x):
    if x[0] in 'aeiou':
        return True 
    else:
        return False

wordlist=['animal', 'coffee', 'python','unit','knowledge','tread','arise']
vowels=[]
for i in wordlist:
    vowels.append(vowel(i))
zipped=zip(wordlist,vowels)
words=dict(zipped)
answer_32=words

# %%
assert answer_32 == {i: i[0] in 'aeiou' for i in W}
assert sorted(answer_32) == sorted(W)

# %% [markdown]
# > **Ex. 3.3.2:** use the `requests` module (get it with `pip install requests`) and `construct_link()` which you defined in the previous question (ex 3.3.1) to request birth data from the "FOD" table. Get all available years (variable "Tid"), but only female births (BARNKON=P) . Unpack the json payload and store the result. Wrap the whole thing in a function which takes an url as input and returns the corresponding output.
# >
# > Store the birth data in a new variable called `answer_33`.
# >
# >> _Hint:_ The `requests.response` object has a `.json()` method.
# >
# >> _Note:_ you wrote `construct_link()` in 3.3.1, if you didn't heres the link you need to get: `https://api.statbank.dk/v1/data/FOLK1A/JSONSTAT?lang=en&Tid=*`

# %%
# [Answer to Ex. 3.3.2 here]

# answer_33 = 

# YOUR CODE HERE

def link(id,list):
    root = 'https://api.statbank.dk/v1/data/'
    url = root + id + '/JSONSTAT?' + '&'.join(list)
    rep = requests.get(url)
    return rep.json()

answer_33 = link('FOD',['Tid=*','BARNKON=P'])

answer_33
# Out:
# {'dataset': {'dimension': {'BARNKON': {'label': 'barnets køn',
#     'category': {'index': {'P': 0}, 'label': {'P': 'Piger'}}},
#    'ContentsCode': {'label': 'Indhold',
#     'category': {'index': {'FOD': 0},
#      'label': {'FOD': 'Levendefødte'},
#      'unit': {'FOD': {'base': 'antal', 'decimals': 0}}}},
#    'Tid': {'label': 'tid',
#     'category': {'index': {'1973': 0,
#       '1974': 1,
#       '1975': 2,
#       '1976': 3,
#       '1977': 4,
#       '1978': 5,
#       '1979': 6,
#       '1980': 7,
#       '1981': 8,
#       '1982': 9,
#       '1983': 10,
#       '1984': 11,
#       '1985': 12,
#       '1986': 13,
#       '1987': 14,
#       '1988': 15,
#       '1989': 16,
#       '1990': 17,
#       '1991': 18,
#       '1992': 19,
#       '1993': 20,
#       '1994': 21,
#       '1995': 22,
#       '1996': 23,
#       '1997': 24,
#       '1998': 25,
#       '1999': 26,
#       '2000': 27,
#       '2001': 28,
#       '2002': 29,
#       '2003': 30,
#       '2004': 31,
#       '2005': 32,
#       '2006': 33,
#       '2007': 34,
#       '2008': 35,
#       '2009': 36,
#       '2010': 37,
#       '2011': 38,
#       '2012': 39,
#       '2013': 40,
#       '2014': 41,
#       '2015': 42,
#       '2016': 43,
#       '2017': 44,
#       '2018': 45},
#      'label': {'1973': '1973',
#       '1974': '1974',
#       '1975': '1975',
#       '1976': '1976',
#       '1977': '1977',
#       '1978': '1978',
#       '1979': '1979',
#       '1980': '1980',
#       '1981': '1981',
#       '1982': '1982',
#       '1983': '1983',
#       '1984': '1984',
#       '1985': '1985',
#       '1986': '1986',
#       '1987': '1987',
#       '1988': '1988',
#       '1989': '1989',
#       '1990': '1990',
#       '1991': '1991',
#       '1992': '1992',
#       '1993': '1993',
#       '1994': '1994',
#       '1995': '1995',
#       '1996': '1996',
#       '1997': '1997',
#       '1998': '1998',
#       '1999': '1999',
#       '2000': '2000',
#       '2001': '2001',
#       '2002': '2002',
#       '2003': '2003',
#       '2004': '2004',
#       '2005': '2005',
#       '2006': '2006',
#       '2007': '2007',
#       '2008': '2008',
#       '2009': '2009',
#       '2010': '2010',
#       '2011': '2011',
#       '2012': '2012',
#       '2013': '2013',
#       '2014': '2014',
#       '2015': '2015',
#       '2016': '2016',
#       '2017': '2017',
#       '2018': '2018'}}},
#    'id': ['BARNKON', 'ContentsCode', 'Tid'],
#    'size': [1, 1, 46],
#    'role': {'metric': ['ContentsCode'], 'time': ['Tid']}},
#   'label': 'Levendefødte efter barnets køn, Indhold og tid',
#   'source': 'Danmarks Statistik',
#   'updated': '2019-02-11T07:00:00Z',
#   'value': [34996,
#    34771,
#    35260,
#    31533,
#    30055,
#    30161,
#    28909,
#    27941,
#    25972,
#    25595,
#    24821,
#    25228,
#    26284,
#    26878,
#    27142,
#    28520,
#    29876,
#    30813,
#    31353,
#    32914,
#    32760,
#    34027,
#    33885,
#    32819,
#    32899,
#    32116,
#    32341,
#    32652,
#    31961,
#    31109,
#    31441,
#    31539,
#    31459,
#    31580,
#    31267,
#    31507,
#    30557,
#    30946,
#    28984,
#    28131,
#    27283,
#    27616,
#    28357,
#    29833,
#    29930,
#    29865]}}

# %%
assert sorted(answer_33['dataset'].keys()) == ['dimension', 'label', 'source', 'updated', 'value']
assert 'BARNKON' in answer_33['dataset']['dimension'].keys()

# %% [markdown]
# ## Problems from exercise set 4

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# > **Ex. 4.1.1:** Use Pandas' CSV reader to fetch  daily data weather from 1864 for various stations - available [here](https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/). Store the dataframe in a variable called `answer_41`.
# >
# >> *Hint 1*: for compressed files you may need to specify the keyword `compression`.
# >
# >> *Hint 2*: keyword `header` can be specified as the CSV has no column names.
# >
# >> *Hint 3*: Specify the path, as the URL linking directly to the 1864 file.

# %%
# [Answer to Ex. 4.1.1 here]

# YOUR CODE HERE

import pandas as pd

url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/1864.csv.gz'

answer_41 = pd.read_csv(url,compression='gzip',header=None)
# Out:
# (27349, 8)

# %%
assert answer_41.shape == (27349, 8)
assert list(answer_41.columns) == list(range(8))

# %% [markdown]
# > **Ex. 4.1.2:** Structure your weather DataFrame by using only the relevant columns (station identifier, data, observation type, observation value), rename them. Make sure observations are correctly formated (how many decimals should we add? one?).
# >
# > Store the resulting dataframe in a new variable called `answer_42`.
# >
# >> *Hint:* rename can be done with `df.columns=COLS` where `COLS` is a list of column names.

# %%
# [Answer to Ex. 4.1.2 here]

# answer_42 = 

# YOUR CODE HERE

answer_42 = answer_41.iloc[:,:4]
answer_42.columns = ['station', 'datetime', 'obs_type', 'obs_value']
answer_42['obs_value'] = answer_42['obs_value'] / 10
answer_42.head()
# Out:
#        station  datetime obs_type  obs_value
# 0  ITE00100550  18640101     TMAX        1.0
# 1  ITE00100550  18640101     TMIN       -2.3
# 2  ITE00100550  18640101     PRCP        2.5
# 3  ASN00079028  18640101     PRCP        0.0
# 4  USC00064757  18640101     PRCP       11.9

# %%
assert answer_42.shape == (27349, 4)
assert 144.8 in [answer_42[i].max() for i in answer_42]
assert -666.0 in [answer_42[i].min() for i in answer_42]
assert 18640101 in [answer_42[i].min() for i in answer_42]

# %% [markdown]
# > **Ex. 4.1.3:**  Select data for the station `ITE00100550` and only observations for maximal temperature. Make a copy of the DataFrame. Explain in a one or two sentences how copying works.
# >
# > Store the subsetted dataframe in a new variable called `answer_43`.
# >
# >> *Hint 1*: the `&` operator works elementwise on boolean series (like `and` in core python).
# >
# >> *Hint 2*: copying of the dataframe is done with the `copy` method for DataFrames.

# %%
# [Answer to Ex. 4.1.3 here]


# YOUR CODE HERE
answer_43 = answer_42[(answer_42.station == 'ITE00100550') & (answer_42.obs_type == 'TMAX')].copy()

# How copying does work:

# %%
assert 'ITE00100550' in [answer_43[i].min() for i in answer_43]
assert 'ITE00100550' in [answer_43[i].max() for i in answer_43]
assert 'TMAX' in [answer_43[i].min() for i in answer_43]
assert 'TMAX' in [answer_43[i].max() for i in answer_43]

# %% [markdown]
# > **Ex. 4.1.4:** Make a new column in `answer_44` called `TMAX_F` where you have converted the temperature variables to Fahrenheit. Make sure not to overwrite `answer_43`.
# >
# > Store the resulting dataframe in a variable called `answer_44`.
# >
# >> *Hint*: Conversion is $F = 32 + 1.8*C$ where $F$ is Fahrenheit and $C$ is Celsius.

# %%
# [Answer to Ex. 4.1.4 here]
answer_44 = answer_43.copy()

# YOUR CODE HERE
answer_44['TMAX_F'] = 32 + 1.8 * answer_44['obs_value']

# %%
assert set(answer_44.columns) -  set(answer_43.columns) == {'TMAX_F'}

# %% [markdown]
# ## Problems from exercise set 5

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns 

# %matplotlib inline 

iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')

# %% [markdown]
# > **Ex. 5.1.1:**: Show the first five rows of the titanic dataset. What information is in the dataset? Use a barplot to show the probability of survival for men and women within each passenger class. Can you make a boxplot showing the same information (why/why not?). _Bonus:_ show a boxplot for the fare-prices within each passenger class.
# >
# > Spend five minutes discussing what you can learn about the survival-selection aboard titanic from the figure(s).
# >
# > > _Hint:_ https://seaborn.pydata.org/generated/seaborn.barplot.html, specifically the `hue` option.

# %%
# [Answer to Ex. 5.1.1 here]

# YOUR CODE HERE

titanic =sns.load_dataset('titanic')
print(titanic.loc[range(5)])

f=sns.barplot(x='sex',y='survived',data=titanic)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
f2=sns.boxplot(x='sex',y='survived',data=titanic)

# %% [markdown]
# > **Ex. 5.1.2:** Using the iris flower dataset, draw a scatterplot of sepal length and petal length. Include a second order polynomial fitted to the data. Add a title to the plot and rename the axis labels.
# > _Discuss:_ Is this a meaningful way to display the data? What could we do differently?
# >
# > For a better understanding of the dataset this image might be useful:
# > <img src="iris_pic.png" alt="Drawing" style="width: 200px;"/>
# >
# >> _Hint:_ use the `.regplot` method from seaborn.

# %%
# [Answer to Ex. 5.1.2 here]

# YOUR CODE HERE

iris =sns.load_dataset('iris')
print(iris.loc[range(5)])
sns.regplot(x=iris['sepal_length'],y=iris['petal_length'], order=2).set_title('Iris')
plt.xlabel('Sepal lenght')
plt.ylabel('Petal length')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Text(0, 0.5, 'Petal length')

# %% [markdown]
# > **Ex. 5.1.3:** Combine the two of the figures you created above into a two-panel figure similar to the one shown here:
# > <img src="Example.png" alt="Drawing" style="width: 600px;"/>
# >
# > Save the figure as a png file on your computer.
# >> _Hint:_ See [this question](https://stackoverflow.com/questions/41384040/subplot-for-seaborn-boxplot) on stackoverflow for inspiration.

# %%
# [Answer to Ex. 5.1.3 here]

# YOUR CODE HERE
fig, axes =plt.subplots(1,2)

sns.regplot(x=iris['sepal_length'],y=iris['petal_length'], order=2, ax=axes[0]).set_title('Iris')
sns.barplot(x='sex',y='survived',data=titanic, ax=axes[1]).set_title('Titianic')
plt.tight_layout()
fig.savefig('plotE.png')

# %% [markdown]
# > **Ex. 5.1.4:** Use [pairplot with hue](https://seaborn.pydata.org/generated/seaborn.pairplot.html) to create a figure that clearly shows how the different species vary across measurements. Change the color palette and remove the shading from the density plots. _Bonus:_ Try to explain how the `diag_kws` argument works (_hint:_ [read here](https://stackoverflow.com/questions/1769403/understanding-kwargs-in-python))

# %%
# [Answer to Ex. 5.1.4 here]

# YOUR CODE HERE
plt.style.use('default')
sns.set_palette("pastel")
f=sns.pairplot(iris, height=2.3, hue='species', diag_kws=dict(shade=False))

# %% [markdown]
# ## Problems from exercise set 6
#
# > _Note:_ In the exercises we asked you to download weather data from the NOAA website. For this assignment the data are loaded in the following code cell into two pandas dataframes.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

weather_1864 = pd.read_csv('weather_data_1864.csv')

# %% [markdown]
# > **Ex. 6.1.4:** Extract the country code from the station name into a separate column.
# >
# > Create a new column in `weather_1864` called `answer_61` and store the country codes here.
# >
# >> _Hint:_ The station column contains a GHCND ID, given to each weather station by NOAA. The format of these ID's is a 2-3 letter country code, followed by a integer identifying the specific station. A simple approach is to assume a fixed length of the country ID. A more complex way would be to use the [`re`](https://docs.python.org/2/library/re.html) module.

# %%
# [Answer to Ex. 6.1.4]
# weather_1864['answer_61'] =

# YOUR CODE HERE
weather_1864['answer_61'] = weather_1864['station']
weather_1864['answer_61'] = weather_1864['country'].str[0:2]

weather_1864.head()
# Out:
#        station  datetime obs_type  obs_value  TMAX_F datetime_dt country  \
# 0  SZ000006717  18640226     TMAX      -34.0  -29.20  1864-02-26     SZ0
# 1  SZ000006717  18640208     TMAX      -17.4    0.68  1864-02-08     SZ0
# 2  CA006158350  18640217     TMAX      -16.7    1.94  1864-02-17     CA0
# 3  SZ000006717  18640103     TMAX      -16.5    2.30  1864-01-03     SZ0
# 4  CA006158350  18640102     TMAX      -16.1    3.02  1864-01-02     CA0
#
#   answer_61
# 0        SZ
# 1        SZ
# 2        CA
# 3        SZ
# 4        CA

# %%
assert sorted(weather_1864['answer_61'].str[:2].unique()) == sorted(['SZ', 'CA', 'EZ', 'GM', 'AU', 'IT', 'BE', 'UK', 'EI', 'AG', 'AS'])

# %% [markdown]
# > **Ex. 6.1.5:** Make a function that downloads and formats the weather data according to previous exercises in Exercise Section 4.1, 6.1. You should use data for ALL stations but still only select maximal temperature. _Bonus:_ To validate that your function works plot the temperature curve for each country in the same window. Use `plt.legend()` to add a legend.
# >
# > Name your function `prepareWeatherData`.

# %%
# [Answer to Ex. 6.1.5]

def prepareWeatherData(year):
    url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/{y}.csv.gz'.format(y=str(year))

    df_weather = pd.read_csv(url, header=None).iloc[:,:4]
    
    df_weather.columns = ['station', 'datetime', 'obs_type', 'obs_value']
    df_weather['obs_value'] = df_weather['obs_value'] / 10  
    df_select = df_weather[(df_weather.obs_type == 'TMAX')].copy()
    df_select['TMAX_F'] = 32 + 1.8 * df_select['obs_value']
    df_sorted = df_select.reset_index(drop=True).sort_values(by=['obs_value'])
    df_sorted['year'] = year
    
    return df_sorted

# %%
assert prepareWeatherData('1864').shape == (5686, 6)

# %%
prepareWeatherData('1864')
# Out:
#           station  datetime obs_type  obs_value  TMAX_F  year
# 845   SZ000006717  18640226     TMAX      -34.0  -29.20  1864
# 577   SZ000006717  18640208     TMAX      -17.4    0.68  1864
# 699   CA006158350  18640217     TMAX      -16.7    1.94  1864
# 42    SZ000006717  18640103     TMAX      -16.5    2.30  1864
# 16    CA006158350  18640102     TMAX      -16.1    3.02  1864
# 607   SZ000006717  18640210     TMAX      -15.9    3.38  1864
# 199   EZE00100082  18640114     TMAX      -15.1    4.82  1864
# 592   SZ000006717  18640209     TMAX      -15.0    5.00  1864
# 741   SZ000006717  18640219     TMAX      -14.7    5.54  1864
# 533   SZ000006717  18640205     TMAX      -14.4    6.08  1864
# 756   SZ000006717  18640220     TMAX      -14.2    6.44  1864
# 229   EZE00100082  18640116     TMAX      -14.2    6.44  1864
# 714   CA006158350  18640218     TMAX      -13.9    6.98  1864
# 562   SZ000006717  18640207     TMAX      -13.8    7.16  1864
# 184   EZE00100082  18640113     TMAX      -13.8    7.16  1864
# 726   SZ000006717  18640218     TMAX      -13.3    8.06  1864
# 69    GM000004204  18640105     TMAX      -12.5    9.50  1864
# 243   EZE00100082  18640117     TMAX      -12.2   10.04  1864
# 273   EZE00100082  18640119     TMAX      -12.2   10.04  1864
# 54    GM000004204  18640104     TMAX      -12.1   10.22  1864
# 5559  SZ000006717  18641223     TMAX      -11.8   10.76  1864
# 5531  CA006158350  18641222     TMAX      -11.7   10.94  1864
# 265   SZ000006717  18640118     TMAX      -11.6   11.12  1864
# 622   SZ000006717  18640211     TMAX      -11.6   11.12  1864
# 49    GME00125218  18640104     TMAX      -11.5   11.30  1864
# 1334  SZ000006717  18640330     TMAX      -11.3   11.66  1864
# 5597  EZE00100082  18641226     TMAX      -11.2   11.84  1864
# 72    SZ000006717  18640105     TMAX      -11.1   12.02  1864
# 5567  EZE00100082  18641224     TMAX      -11.0   12.20  1864
# 28    SZ000006717  18640102     TMAX      -10.7   12.74  1864
# ...           ...       ...      ...        ...     ...   ...
# 3568  AGE00135039  18640819     TMAX       33.0   91.40  1864
# 3240  ITE00100554  18640729     TMAX       33.0   91.40  1864
# 3358  ITE00100550  18640806     TMAX       33.1   91.58  1864
# 3287  ITE00100554  18640801     TMAX       33.1   91.58  1864
# 1084  ASN00086071  18640314     TMAX       33.3   91.94  1864
# 5183  ASN00086071  18641130     TMAX       33.3   91.94  1864
# 3407  CA006158350  18640809     TMAX       33.3   91.94  1864
# 5309  ASN00086071  18641208     TMAX       33.3   91.94  1864
# 3413  ITE00100554  18640809     TMAX       33.4   92.12  1864
# 3279  ITE00100550  18640801     TMAX       33.5   92.30  1864
# 3342  ITE00100550  18640805     TMAX       33.5   92.30  1864
# 3381  ITE00100554  18640807     TMAX       33.6   92.48  1864
# 290   ASN00066062  18640120     TMAX       33.9   93.02  1864
# 2696  CA006158350  18640625     TMAX       33.9   93.02  1864
# 30    ASN00086071  18640103     TMAX       33.9   93.02  1864
# 5545  ASN00086071  18641223     TMAX       33.9   93.02  1864
# 3423  CA006158350  18640810     TMAX       33.9   93.02  1864
# 3397  ITE00100554  18640808     TMAX       33.9   93.02  1864
# 3189  AGE00135039  18640726     TMAX       34.0   93.20  1864
# 3389  ITE00100550  18640808     TMAX       34.1   93.38  1864
# 379   ASN00066062  18640126     TMAX       34.3   93.74  1864
# 52    ASN00066062  18640104     TMAX       34.3   93.74  1864
# 3391  CA006158350  18640808     TMAX       34.4   93.92  1864
# 713   ASN00086071  18640218     TMAX       34.5   94.10  1864
# 3294  ITE00100550  18640802     TMAX       34.6   94.28  1864
# 3366  ITE00100554  18640806     TMAX       34.7   94.46  1864
# 3405  ITE00100550  18640809     TMAX       34.8   94.64  1864
# 3350  ITE00100554  18640805     TMAX       35.5   95.90  1864
# 3302  ITE00100554  18640802     TMAX       35.6   96.08  1864
# 104   ASN00086071  18640108     TMAX       35.9   96.62  1864
#
# [5686 rows x 6 columns]

# %% [markdown]
# ## Problems from exercise set 7
#
# > _Note:_ Once again if you haven't managed to download the data from NOAA, you can refer to the github repo to get csv-files containing the required data.

# %%
# %matplotlib inline 

import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib as mpl

# Increases the plot size a little
mpl.rcParams['figure.figsize'] = 11, 6

# %%
def weatherdata(yr):
    url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/by_year/'+str(yr)+'.csv.gz'
    df = pd.read_csv(url, sep=',',compression="gzip",header=None)
    df1 = df.drop(columns=[4,5,6,7])
    df1.columns = ['station','date','type','temp']
    df1_max = df1.loc[(df1['type']=='TMAX')]
    df1_max['TMAX_F'] = df1_max['temp']*1.8+32
    df1_max.reset_index(inplace=True, drop=True)
    df1_max.sort_values(by='temp', inplace=True)
    df1_max['date'] = pd.to_datetime(df1_max['date'], format='%Y%m%d')
    df1_max['month'] = df1_max['date'].dt.month
    df1_max.set_index(df1_max['date'], inplace=True)
    df1_max['countrycode'] = df1_max['station'].str.extract('([A-Z]+)')
    return df1_max

# %% [markdown]
# > **Ex. 7.1.1:** Plot the monthly max,min, mean, first and third quartiles for maximum temperature for our station with the ID _'ITE00100550'_ in 1864.
#
# > *Hint*: the method `describe` computes all these measures.

# %%
# [Answer to Ex. 7.1.1]

# YOUR CODE HERE
data = weatherdata('1864')

ite = data.loc[(data['station']=='ITE00100550') & (data['type']=='TMAX')].copy()
ite.groupby("month")["temp"].describe().plot(y=["25%", "75%", "min", "mean", "max"])
#data.head()
# Out:
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %% [markdown]
# > **Ex. 7.1.2:** Get the processed data from years 1864-1867 as a list of DataFrames. Convert the list into a single DataFrame by concatenating vertically.
# >
# > Name the concatenated data `answer_72`

# %%
# [Answer to Ex. 7.1.2]

# YOUR CODE HERE
data1 = weatherdata(1865)
data2 = weatherdata(1866)
data3 = weatherdata(1867)

# vertical concetenation
answer_72=pd.concat([data,data1,data2,data3], join='outer', axis=0)
answer_72.head(4)
# Out:
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\fleig\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
#                 station       date  type  temp  TMAX_F  month countrycode
# date
# 1864-02-26  SZ000006717 1864-02-26  TMAX  -340  -580.0      2          SZ
# 1864-02-08  SZ000006717 1864-02-08  TMAX  -174  -281.2      2          SZ
# 1864-02-17  CA006158350 1864-02-17  TMAX  -167  -268.6      2          CA
# 1864-01-03  SZ000006717 1864-01-03  TMAX  -165  -265.0      1          SZ

# %%
answer_72.shape
# Out:
# (30003, 7)

# %%
assert answer_72.shape == (30003, 7)

# %% [markdown]
# > **Ex. 7.1.3:** Parse the station location data which you can find at https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt. Merge station locations onto the weather data spanning 1864-1867.
# >
# > Store the merged data in a new variable called `answer_73`.
# >
# > _Hint:_ The location data have the folllowing format,
#
# ```
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------
# ```
#
# > *Hint*: The station information has fixed width format - does there exist a pandas reader for that?

# %%
# [Answer to Ex. 7.1.3]

# YOUR CODE HERE
url = 'https://www1.ncdc.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt'

# fixed width format
df_location = pd.read_fwf(url)

df_location.columns=['station','latitude','longitude','elevation','name','gsn_flag','hcn_crn_flag','wmo_id']
df_location["random"] = df_location["elevation"]

print(df_location.head())
# Out:
#        station  latitude  longitude  elevation                 name gsn_flag  \
# 0  ACW00011647   17.1333   -61.7833       19.2             ST JOHNS      NaN
# 1  AE000041196   25.3330    55.5170       34.0  SHARJAH INTER. AIRP      NaN
# 2  AEM00041194   25.2550    55.3640       10.4           DUBAI INTL      NaN
# 3  AEM00041217   24.4330    54.6510       26.8       ABU DHABI INTL      NaN
# 4  AEM00041218   24.2620    55.6090      264.9          AL AIN INTL      NaN
#
#   hcn_crn_flag   wmo_id  random
# 0          NaN      NaN    19.2
# 1          GSN  41196.0    34.0
# 2          NaN  41194.0    10.4
# 3          NaN  41217.0    26.8
# 4          NaN  41218.0   264.9

# %%
answer_73 = pd.merge(answer_72,df_location, how='inner')
answer_73.head(4)
# Out:
#        station       date  type  temp  TMAX_F  month countrycode  latitude  \
# 0  SZ000006717 1864-02-26  TMAX  -340  -580.0      2          SZ   45.8667
# 1  SZ000006717 1864-02-08  TMAX  -174  -281.2      2          SZ   45.8667
# 2  SZ000006717 1864-01-03  TMAX  -165  -265.0      1          SZ   45.8667
# 3  SZ000006717 1864-02-10  TMAX  -159  -254.2      2          SZ   45.8667
#
#    longitude  elevation                     name gsn_flag hcn_crn_flag  \
# 0     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
# 1     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
# 2     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
# 3     7.1667     2472.0  COL DU GRAND ST-BERNARD      NaN          GSN
#
#    wmo_id  random
# 0  6717.0  2472.0
# 1  6717.0  2472.0
# 2  6717.0  2472.0
# 3  6717.0  2472.0

# %%
answer_73.shape
# Out:
# (30003, 15)

# %%
assert answer_73.shape == (5686, 15) or answer_73.shape == (30003, 15)

# %% [markdown]
# ## Problems from exercise set 8
#
# > **Ex. 8.1.2.:** Use the `request` module to collect the first page of job postings.
# >
# > Store the response.json() object in a new variable called `answer_81`.
# >

# %%
# [Answer to Ex. 8.1.2]

# YOUR CODE HERE
import pandas as pd
import requests
url = 'https://job.jobnet.dk/CV/FindWork/Search'

r = requests.get(url)
r.status_code
answer_81 = r.json()

# %%
assert sorted(answer_81.keys()) == sorted(['Expression', 'Facets', 'JobPositionPostings', 'TotalResultCount'])

# %% [markdown]
# > **Ex. 8.1.3.:** Store the 'TotalResultCount' value for later use. Also create a dataframe from the 'JobPositionPostings' field in the json. Name this dataframe `answer_82`.

# %%
# [Answer to Ex. 8.1.3]
# answer_82 = 

# YOUR CODE HERE
answer_82 = pd.DataFrame((answer_81['JobPositionPostings']))
answer_82.head(20)
# Out:
#     AnonymousEmployer  AssignmentStartDate  AutomatchType  Country  \
# 0               False  0001-01-01T00:00:00              0  Danmark
# 1               False  0001-01-01T00:00:00              0  Danmark
# 2               False  0001-01-01T00:00:00              0  Danmark
# 3               False  0001-01-01T00:00:00              0  Danmark
# 4               False  0001-01-01T00:00:00              0  Danmark
# 5               False  0001-01-01T00:00:00              0  Danmark
# 6               False  0001-01-01T00:00:00              0  Danmark
# 7               False  0001-01-01T00:00:00              0  Danmark
# 8               False  0001-01-01T00:00:00              0  Danmark
# 9               False  0001-01-01T00:00:00              0  Danmark
# 10              False  0001-01-01T00:00:00              0  Danmark
# 11              False  0001-01-01T00:00:00              0  Danmark
# 12              False  0001-01-01T00:00:00              0  Danmark
# 13              False  0001-01-01T00:00:00              0  Danmark
# 14              False  0001-01-01T00:00:00              0  Danmark
# 15              False  0001-01-01T00:00:00              0  Danmark
# 16              False  0001-01-01T00:00:00              0  Danmark
# 17              False  0001-01-01T00:00:00              0  Danmark
# 18              False  0001-01-01T00:00:00              0   Cypern
# 19              False  0001-01-01T00:00:00              0  Danmark
#
#                                            DetailsUrl EmploymentType  \
# 0   https://job.jobnet.dk/CV/FindWork/Details/5031556
# 1   https://job.jobnet.dk/CV/FindWork/Details/5031555
# 2   https://job.jobnet.dk/CV/FindWork/Details/5031554
# 3   https://job.jobnet.dk/CV/FindWork/Details/5031553
# 4   https://job.jobnet.dk/CV/FindWork/Details/5031549
# 5   https://job.jobnet.dk/CV/FindWork/Details/5031550
# 6   https://job.jobnet.dk/CV/FindWork/Details/5031547
# 7   https://job.jobnet.dk/CV/FindWork/Details/5031548
# 8   https://job.jobnet.dk/CV/FindWork/Details/5031545
# 9   https://job.jobnet.dk/CV/FindWork/Details/5031546
# 10  https://job.jobnet.dk/CV/FindWork/Details/5031538
# 11  https://job.jobnet.dk/CV/FindWork/Details/5031544
# 12  https://job.jobnet.dk/CV/FindWork/Details/5031520
# 13  https://job.jobnet.dk/CV/FindWork/Details/5031542
# 14  https://job.jobnet.dk/CV/FindWork/Details/5031518
# 15  https://job.jobnet.dk/CV/FindWork/Details/5031515
# 16  https://job.jobnet.dk/CV/FindWork/Details/5031512
# 17  https://job.jobnet.dk/CV/FindWork/Details/5031514
# 18  https://job.jobnet.dk/CV/FindWork/Details/5031493
# 19  https://job.jobnet.dk/CV/FindWork/Details/5031539
#
#     HasLocationValues  HiringOrgCVR  \
# 0                True      29220824
# 1                True      35759344
# 2                True      36538376
# 3                True      19583910
# 4                True      18158345
# 5                True      29189420
# 6                True      27673120
# 7                True      29190658
# 8                True      26378427
# 9                True      37851582
# 10               True      34076510
# 11               True      29188572
# 12               True      35529586
# 13               True      26370736
# 14               True      29190909
# 15               True      30874323
# 16               True      35529586
# 17               True      43271911
# 18              False      39749327
# 19               True      32825893
#
#                                      HiringOrgName       ID  ...  \
# 0                            Bowl'n'Fun Sønderborg  5031556  ...
# 1                                    KMK Rengøring  5031555  ...
# 2                        TANDLÆGE ANDREA GROTH ApS  5031554  ...
# 3                               Vallensbæk Kommune  5031553  ...
# 4                                        Just Jobs  5031549  ...
# 5                                  Vestbjerg Skole  5031550  ...
# 6                                 NemTimeld.dk ApS  5031547  ...
# 7                                  Region Sjælland  5031548  ...
# 8                      Glitter Rosengårds Centeret  5031545  ...
# 9                 Memox og Øresund Psykoterapi ApS  5031546  ...
# 10                                     Halberg A/S  5031538  ...
# 11                           Borgerskoleafdelingen  5031544  ...
# 12                             Habitus Holding ApS  5031520  ...
# 13            Mac Donald Pub v/Poul Normann Jensen  5031542  ...
# 14                               Region Syddanmark  5031518  ...
# 15  Professionshøjskolen ABSALON i Region Sjælland  5031515  ...
# 16                             Habitus Holding ApS  5031512  ...
# 17                             Udenrigsministeriet  5031514  ...
# 18                             Arbejdeiudlandet.dk  5031493  ...
# 19                       SMP RENGØRINGSSERVICE ApS  5031539  ...
#
#     UseWorkPlaceAddressForJoblog  Weight  WorkHours WorkPlaceAbroad  \
# 0                           True     1.0    Fuldtid           False
# 1                          False     1.0     Deltid           False
# 2                           True     1.0    Fuldtid           False
# 3                           True     1.0     Deltid           False
# 4                          False     1.0    Fuldtid           False
# 5                           True     1.0    Fuldtid           False
# 6                           True     1.0    Fuldtid           False
# 7                          False     1.0    Fuldtid           False
# 8                           True     1.0     Deltid           False
# 9                           True     1.0    Fuldtid           False
# 10                          True     1.0    Fuldtid           False
# 11                          True     1.0    Fuldtid           False
# 12                         False     1.0    Fuldtid           False
# 13                          True     1.0     Deltid           False
# 14                          True     1.0     Deltid           False
# 15                          True     1.0    Fuldtid           False
# 16                         False     1.0     Deltid           False
# 17                          True     1.0    Fuldtid           False
# 18                          True     1.0    Fuldtid           False
# 19                         False     1.0     Deltid           False
#
#                WorkPlaceAddress      WorkPlaceCity WorkPlaceNotStatic  \
# 0           Stenager 17, 1. sal         Sønderborg              False
# 1                                          Kolding              False
# 2                 Vestergade 44           Odense C              False
# 3   Vallensbæk Stationstorv 100  Vallensbæk Strand              False
# 4                                                                True
# 5               Bakmøllevej 280          Vestbjerg              False
# 6                    Strømmen 6        Nørresundby              False
# 7                  Fælledvej 11           Slagelse              False
# 8                   Ørbækvej 75          Odense SØ              False
# 9                  Eliasgade 10        København S              False
# 10               Porthusvej 100          Svendborg              False
# 11                Skimminge 19A             Maribo              False
# 12           Jernstøbervænget 7               Køge              False
# 13              Nygårds Plads 2            Brøndby              False
# 14                  Damhaven 12              Vejle              False
# 15                Slagelsevej 7               Sorø              False
# 16             Drachmannsvej 6A            Hornbæk              False
# 17             Asiatisk Plads 2        København K              False
# 18               Lautruphøj 1.3           Ballerup              False
# 19                                      Sønderborg              False
#
#    WorkPlaceOtherAddress  WorkPlacePostalCode WorkplaceID
# 0                  False                 6400           0
# 1                   True                 6000      111332
# 2                  False                 5000      132600
# 3                  False                 2665        7542
# 4                  False                           116038
# 5                  False                 9380       96985
# 6                  False                 9400       49184
# 7                   True                 4200       61350
# 8                  False                 5220      132599
# 9                  False                 2300      123290
# 10                 False                 5700           0
# 11                 False                 4930      127167
# 12                  True                 4600      128528
# 13                 False                 2605       77190
# 14                 False                 7100       62490
# 15                 False                 4180       70954
# 16                  True                 3100      128528
# 17                 False                 1402       25577
# 18                 False                 2750           0
# 19                  True                 6400      121939
#
# [20 rows x 44 columns]

# %%
assert answer_82.shape == (20,44)
